# %%
from supabase import create_client
from langchain_community.embeddings import OpenAIEmbeddings
import os
from dotenv import load_dotenv

load_dotenv()

# Initialize your Supabase client here
url = os.getenv("SUPABASE_URL")
key = os.getenv("SUPABASE_KEY")
supabase_client = create_client(url, key)

# %%
import requests
import json
import os
import sys
import time
import asyncio
from datetime import datetime, timedelta
import logging
from typing import List, Dict, Optional
from dataclasses import dataclass
import hashlib
import openai

# sys.path.append(os.path.abspath(os.path.join(os.path.dirname(__file__), '..')))
# from utils.supabase_client import supabase_client
from bse_data_collection import get_all_data_from_name
# from data_collection.bse_data_collection import get_all_data_from_name, download_pdf_from_link, generate_summary
from utils.database.retrival_utils import get_company_name
from utils.queue_processor import AnnouncementQueue, QueueItem

BASE_URL = "https://api.bseindia.com/BseIndiaAPI/api/AnnSubCategoryGetData/w"
headers = {
            "referer": "https://www.bseindia.com/",
            "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.0.0 Safari/537.36"
        }

def _get_date_params() -> tuple:
        """Get today's date parameters in required format"""
        today = datetime.now()
        return (today.strftime("%Y%m%d"), today.strftime("%Y%m%d"))

def _generate_hash(content: str) -> str:
        """Generate hash for announcement content"""
        return hashlib.sha256(content.encode('utf-8')).hexdigest()

def _check_existing_announcement(pdf_name: str) -> bool:
        """Check if announcement already exists in database"""
        try:
            response = supabase_client.table('recent_announcements_2')\
                .select('content')\
                .eq('content', pdf_name)\
                .execute()
            return len(response.data) > 0
        except Exception as e:
            print(f"Error checking existing announcement: {e}")
            return False
        
def remove_duplicate_scrips(data_list):
    """
    Remove duplicate entries from a list of dictionaries based on SCRIP_CD,
    keeping only the first occurrence of each SCRIP_CD.
    
    Parameters:
    data_list (list): List of dictionaries containing stock market data
    
    Returns:
    list: List of dictionaries with duplicate SCRIP_CD entries removed
    """
    seen_scrip_codes = set()
    unique_data = []
    
    for entry in data_list:
        scrip_code = entry.get('SCRIP_CD')
        if scrip_code not in seen_scrip_codes:
            seen_scrip_codes.add(scrip_code)
            unique_data.append(entry)
    
    return unique_data

def fetch_new_announcements() -> List[Dict]:
        """Fetch new announcements from BSE API"""
        from_date, to_date = _get_date_params()
        
        params = {
            "pageno": "1",
            "strCat": "-1",  # All categories
            "strPrevDate": from_date,
            "strScrip": "",  # All scripts
            "strSearch": "P",
            "strToDate": to_date,
            "strType": "C",
            "subcategory": "-1"
        }

        try:
            response = requests.get(
                BASE_URL,
                params=params,
                headers=headers,
                timeout=30
            )
            response.raise_for_status()
            
            data = response.json()
            if "Table" not in data:
                print("No announcements found in response")
                return []
                
            return remove_duplicate_scrips(data["Table"])
            
        except requests.exceptions.RequestException as e:
            print(f"Error fetching announcements: {e}")
            return []

# %%
res = fetch_new_announcements()

# %%
res
# Out:
# [{'NEWSID': 'ddec7e08-d794-46bc-8d98-b54c70bfd5fb',
#   'SCRIP_CD': 532015,
#   'XML_NAME': 'ANN_532015_DDEC7E08-D794-46BC-8D98-B54C70BFD5FB',
#   'NEWSSUB': 'GRAVITY (INDIA) LTD.-$ - 532015 - Disclosures under Reg. 29(2) of SEBI (SAST) Regulations, 2011',
#   'DT_TM': '2024-12-19T14:44:12.283',
#   'NEWS_DT': '2024-12-19T14:44:12.283',
#   'CRITICALNEWS': 0,
#   'ANNOUNCEMENT_TYPE': 'A',
#   'QUARTER_ID': None,
#   'FILESTATUS': 'N    ',
#   'ATTACHMENTNAME': 'DDEC7E08_D794_46BC_8D98_B54C70BFD5FB_144406.pdf',
#   'MORE': '',
#   'HEADLINE': 'The Exchange has received the disclosure under Regulation 29(2) of SEBI (Substantial Acquisition of Shares & Takeovers) Regulations, 2011 for Sanjeev Lunkad & PACs',
#   'CATEGORYNAME': 'Insider Trading / SAST',
#   'OLD': 1,
#   'RN': 1,
#   'PDFFLAG': 0,
#   'NSURL': 'https://www.bseindia.com/stock-share-price/gravity-(india)-ltd/gravity/532015/',
#   'SLONGNAME': 'GRAVITY (INDIA) LTD.-$',
#   'AGENDA_ID': 57,
#   'TotalPageCnt': 4,
#   'News_submission_dt': None,
#   'DissemDT': '2024-12-19T14:44:12.283',
#   'TimeDiff': None,
#   'Fld_Attachsize': 8705002,
#   'SUBCATNAME': 'Disclosures under Reg. 29(2) of SEBI (SAST) Regulations, 2011',
#   'AUDIO_VIDEO_FILE': None},
#  {'NEWSID': 'c302eaf9-1eb2-400c-81bd-b931540c9f31',
#   'SCRIP_CD': 541143,
#   'XML_NAME': 'ANN_541143_C302EAF9-1EB2-400C-81BD-B931540C9F31',
#   'NEWSSUB': 'Bharat Dynamics Ltd - 541143 - Allotment Of DIN To Shri G Gayatri Prasad Director Finance',
#   'DT_TM': '2024-12-19T14:42:26.973',
#   'NEWS_DT': '2024-12-19T14:42:26.973',
#   'CRITICALNEWS': 0,
#   'ANNOUNCEMENT_TYPE': 'A',
#   'QUARTER_ID': None,
#   'FILESTATUS': 'N    ',
#   'ATTACHMENTNAME': 'f3c61c91-f90b-41c2-8263-7fc45e7d8cba.pdf',
#   'MORE': '',
#   'HEADLINE': 'Allotment of DIN to Shri G Gayatri Prasad Director Finance',
#   'CATEGORYNAME': 'Company Update',
#   'OLD': 1,
#   'RN': 1,
#   'PDFFLAG': 0,
#   'NSURL': 'https://www.bseindia.com/stock-share-price/bharat-dynamics-ltd/bdl/541143/',
#   'SLONGNAME': 'Bharat Dynamics Ltd',
#   'AGENDA_ID': 1,
#   'TotalPageCnt': 4,
#   'News_submission_dt': '2024-12-19T14:42:26',
#   'DissemDT': '2024-12-19T14:42:26.973',
#   'TimeDiff': '00:00:00',
#   'Fld_Attachsize': 253270,
#   'SUBCATNAME': 'General',
#   'AUDIO_VIDEO_FILE': None},
#  {'NEWSID': 'bf8c2d1b-8a40-4582-a909-fcddb69cba7a',
#   'SCRIP_CD': 532400,
#   'XML_NAME': 'ANN_532400_BF8C2D1B-8A40-4582-A909-FCDDB69CBA7A',
#   'NEWSSUB': 'Birlasoft Ltd - 532400 - Disclosures under Reg. 29(2) of SEBI (SAST) Regulations, 2011',
#   'DT_TM': '2024-12-19T14:41:33.63',
#   'NEWS_DT': '2024-12-19T14:41:33.63',
#   'CRITICALNEWS': 0,
#   'ANNOUNCEMENT_TYPE': 'A',
#   'QUARTER_ID': None,
#   'FILESTATUS': 'N    ',
#   'ATTACHMENTNAME': 'BF8C2D1B_8A40_4582_A909_FCDDB69CBA7A_144128.pdf',
#   'MORE': '',
#   'HEADLINE': 'The Exchange has received the disclosure under Regulation 29(2) of SEBI (Substantial Acquisition of Shares & Takeovers) Regulations, 2011 for Kotak Mahindra Mutual Fund',
#   'CATEGORYNAME': 'Insider Trading / SAST',
#   'OLD': 1,
#   'RN': 1,
#   'PDFFLAG': 0,
#   'NSURL': 'https://www.bseindia.com/stock-share-price/birlasoft-ltd/bsoft/532400/',
#   'SLONGNAME': 'Birlasoft Ltd',
#   'AGENDA_ID': 57,
#   'TotalPageCnt': 4,
#   'News_submission_dt': None,
#   'DissemDT': '2024-12-19T14:41:33.63',
#   'TimeDiff': None,
#   'Fld_Attachsize': 167289,
#   'SUBCATNAME': 'Disclosures under Reg. 29(2) of SEBI (SAST) Regulations, 2011',
#   'AUDIO_VIDEO_FILE': None},
#  {'NEWSID': '69c0e174-c5ff-4ab8-96c0-5b657627db95',
#   'SCRIP_CD': 543227,
#   'XML_NAME': 'ANN_543227_69C0E174-C5FF-4AB8-96C0-5B657627DB95',
#   'NEWSSUB': 'Happiest Minds Technologies Ltd - 543227 - Closure of Trading Window',
#   'DT_TM': '2024-12-19T14:40:52.703',
#   'NEWS_DT': '2024-12-19T14:40:52.703',
#   'CRITICALNEWS': 0,
#   'ANNOUNCEMENT_TYPE': 'A',
#   'QUARTER_ID': None,
#   'FILESTATUS': 'N    ',
#   'ATTACHMENTNAME': 'de24c299-8d81-4012-82d1-4087fc6b5899.pdf',
#   'MORE': '',
#   'HEADLINE': 'Intimation of closure of Trading Window',
#   'CATEGORYNAME': 'Insider Trading / SAST',
#   'OLD': 1,
#   'RN': 1,
#   'PDFFLAG': 0,
#   'NSURL': 'https://www.bseindia.com/stock-share-price/happiest-minds-technologies-ltd/happstmnds/543227/',
#   'SLONGNAME': 'Happiest Minds Technologies Ltd',
#   'AGENDA_ID': 66,
#   'TotalPageCnt': 4,
#   'News_submission_dt': '2024-12-19T14:40:52',
#   'DissemDT': '2024-12-19T14:40:52.703',
#   'TimeDiff': '00:00:00',
#   'Fld_Attachsize': 207268,
#   'SUBCATNAME': 'Closure of Trading Window',
#   'AUDIO_VIDEO_FILE': None},
#  {'NEWSID': '823ab617-9737-4294-ba6a-b354966c666f',
#   'SCRIP_CD': 500413,
#   'XML_NAME': 'ANN_500413_823AB617-9737-4294-BA6A-B354966C666F',
#   'NEWSSUB': 'THOMAS COOK (INDIA) LTD. - 500413 - Announcement under Regulation 30 (LODR)-Analyst / Investor Meet - Intimation',
#   'DT_TM': '2024-12-19T14:36:13.08',
#   'NEWS_DT': '2024-12-19T14:36:13.08',
#   'CRITICALNEWS': 0,
#   'ANNOUNCEMENT_TYPE': 'A',
#   'QUARTER_ID': None,
#   'FILESTATUS': 'N    ',
#   'ATTACHMENTNAME': '3ca75413-d3ae-4ec8-86d8-e93fcf383c7f.pdf',
#   'MORE': 'Pursuant to the Regulation 30 and 46 of SEBI (Listing Obligations and Disclosure Requirements), Regulations 2015, we would like to inform you that the officials of the Company will be interacting with Investor(s)/Analyst(s) as per the details enclosed in the intimation.',
#   'HEADLINE': 'Pursuant to the Regulation 30 and 46 of SEBI (Listing Obligations and Disclosure Requirements), Regulations 2015, we would like to inform you that the officials of the Company will be interacting ....',
#   'CATEGORYNAME': 'Company Update',
#   'OLD': 1,
#   'RN': 1,
#   'PDFFLAG': 0,
#   'NSURL': 'https://www.bseindia.com/stock-share-price/thomas-cook-(india)-ltd/thomascook/500413/',
#   'SLONGNAME': 'THOMAS COOK (INDIA) LTD.',
#   'AGENDA_ID': 80,
#   'TotalPageCnt': 4,
#   'News_submission_dt': '2024-12-19T14:36:12',
#   'DissemDT': '2024-12-19T14:36:13.08',
#   'TimeDiff': '00:00:01',
#   'Fld_Attachsize': 360530,
#   'SUBCATNAME': 'Analyst / Investor Meet',
#   'AUDIO_VIDEO_FILE': None},
#  {'NEWSID': '77d9bf3c-5f2e-4f43-93db-6ebca309a6e8',
#   'SCRIP_CD': 522034,
#   'XML_NAME': 'ANN_522034_77D9BF3C-5F2E-4F43-93DB-6EBCA309A6E8',
#   'NEWSSUB': 'SHANTHI GEARS LTD. - 522034 - Closure of Trading Window',
#   'DT_TM': '2024-12-19T14:35:05.71',
#   'NEWS_DT': '2024-12-19T14:35:05.71',
#   'CRITICALNEWS': 0,
#   'ANNOUNCEMENT_TYPE': 'A',
#   'QUARTER_ID': None,
#   'FILESTATUS': 'N    ',
#   'ATTACHMENTNAME': '240439b7-30e7-4096-bc12-595e8edaaa5b.pdf',
#   'MORE': '',
#   'HEADLINE': 'Closure of Trading Window for the quarter and nine months ending 31st December, 2024.',
#   'CATEGORYNAME': 'Insider Trading / SAST',
#   'OLD': 1,
#   'RN': 1,
#   'PDFFLAG': 0,
#   'NSURL': 'https://www.bseindia.com/stock-share-price/shanthi-gears-ltd/shantigear/522034/',
#   'SLONGNAME': 'SHANTHI GEARS LTD.',
#   'AGENDA_ID': 66,
#   'TotalPageCnt': 4,
#   'News_submission_dt': '2024-12-19T14:35:05',
#   'DissemDT': '2024-12-19T14:35:05.71',
#   'TimeDiff': '00:00:00',
#   'Fld_Attachsize': 609241,
#   'SUBCATNAME': 'Closure of Trading Window',
#   'AUDIO_VIDEO_FILE': None},
#  {'NEWSID': 'da324dfc-e570-4a96-ba41-5a3803948a51',
#   'SCRIP_CD': 539006,
#   'XML_NAME': 'ANN_539006_DA324DFC-E570-4A96-BA41-5A3803948A51',
#   'NEWSSUB': 'PTC Industries Ltd - 539006 - Announcement under Regulation 30 (LODR)-Updates on Acquisition',
#   'DT_TM': '2024-12-19T14:31:06.597',
#   'NEWS_DT': '2024-12-19T14:31:06.597',
#   'CRITICALNEWS': 1,
#   'ANNOUNCEMENT_TYPE': 'A',
#   'QUARTER_ID': None,
#   'FILESTATUS': 'N    ',
#   'ATTACHMENTNAME': '58687b81-4943-4cdf-b93d-52a646753327.pdf',
#   'MORE': '',
#   'HEADLINE': 'As enclosed',
#   'CATEGORYNAME': 'Company Update',
#   'OLD': 1,
#   'RN': 1,
#   'PDFFLAG': 0,
#   'NSURL': 'https://www.bseindia.com/stock-share-price/ptc-industries-ltd/ptcil/539006/',
#   'SLONGNAME': 'PTC Industries Ltd',
#   'AGENDA_ID': 2,
#   'TotalPageCnt': 4,
#   'News_submission_dt': '2024-12-19T14:31:06',
#   'DissemDT': '2024-12-19T14:31:06.597',
#   'TimeDiff': '00:00:00',
#   'Fld_Attachsize': 2277436,
#   'SUBCATNAME': 'Acquisition',
#   'AUDIO_VIDEO_FILE': None},
#  {'NEWSID': '98236462-33c8-419d-9d23-fb80bace652f',
#   'SCRIP_CD': 504614,
#   'XML_NAME': 'ANN_504614_98236462-33C8-419D-9D23-FB80BACE652F',
#   'NEWSSUB': 'SARDA ENERGY & MINERALS LTD.-$ - 504614 - Closure of Trading Window',
#   'DT_TM': '2024-12-19T14:30:04.237',
#   'NEWS_DT': '2024-12-19T14:30:04.237',
#   'CRITICALNEWS': 0,
#   'ANNOUNCEMENT_TYPE': 'A',
#   'QUARTER_ID': None,
#   'FILESTATUS': 'N    ',
#   'ATTACHMENTNAME': '3e5bb1c3-4b01-4815-88a0-4dc9cd0c5da9.pdf',
#   'MORE': '',
#   'HEADLINE': 'Closure of Trading Window',
#   'CATEGORYNAME': 'Insider Trading / SAST',
#   'OLD': 1,
#   'RN': 1,
#   'PDFFLAG': 0,
#   'NSURL': 'https://www.bseindia.com/stock-share-price/sarda-energy--minerals-ltd/sardaen/504614/',
#   'SLONGNAME': 'SARDA ENERGY & MINERALS LTD.-$',
#   'AGENDA_ID': 66,
#   'TotalPageCnt': 4,
#   'News_submission_dt': '2024-12-19T14:30:04',
#   'DissemDT': '2024-12-19T14:30:04.237',
#   'TimeDiff': '00:00:00',
#   'Fld_Attachsize': 175515,
#   'SUBCATNAME': 'Closure of Trading Window',
#   'AUDIO_VIDEO_FILE': None},
#  {'NEWSID': '3d6199d2-80ba-48dd-a43a-9a8e9d6607bc',
#   'SCRIP_CD': 530001,
#   'XML_NAME': 'ANN_530001_3D6199D2-80BA-48DD-A43A-9A8E9D6607BC',
#   'NEWSSUB': 'GUJARAT ALKALIES & CHEMICALS LTD. - 530001 - Intimation Of ESG Rating By SES ESG Research Private Limited.',
#   'DT_TM': '2024-12-19T14:28:52.273',
#   'NEWS_DT': '2024-12-19T14:28:52.273',
#   'CRITICALNEWS': 0,
#   'ANNOUNCEMENT_TYPE': 'A',
#   'QUARTER_ID': None,
#   'FILESTATUS': 'N    ',
#   'ATTACHMENTNAME': '3f118a02-a328-4999-8c41-4ed29625e8e8.pdf',
#   'MORE': '',
#   'HEADLINE': 'We submit herewith ESG rating issued by SES ESG Research Private Limited. For more detail kindly refer attached letter.',
#   'CATEGORYNAME': 'Company Update',
#   'OLD': 1,
#   'RN': 1,
#   'PDFFLAG': 0,
#   'NSURL': 'https://www.bseindia.com/stock-share-price/gujarat-alkalies--chemicals-ltd/gujalkali/530001/',
#   'SLONGNAME': 'GUJARAT ALKALIES & CHEMICALS LTD.',
#   'AGENDA_ID': 1,
#   'TotalPageCnt': 4,
#   'News_submission_dt': '2024-12-19T14:28:52',
#   'DissemDT': '2024-12-19T14:28:52.273',
#   'TimeDiff': '00:00:00',
#   'Fld_Attachsize': 167231,
#   'SUBCATNAME': 'General',
#   'AUDIO_VIDEO_FILE': None},
#  {'NEWSID': '29b37297-02ad-4aaf-bd1a-75b5e217eb0f',
#   'SCRIP_CD': 526871,
#   'XML_NAME': 'ANN_526871_29B37297-02AD-4AAF-BD1A-75B5E217EB0F',
#   'NEWSSUB': 'INTEC CAPITAL LTD. - 526871 - Announcement under Regulation 30 (LODR)-Resignation of Company Secretary / Compliance Officer',
#   'DT_TM': '2024-12-19T14:25:41.333',
#   'NEWS_DT': '2024-12-19T14:25:41.333',
#   'CRITICALNEWS': 0,
#   'ANNOUNCEMENT_TYPE': 'A',
#   'QUARTER_ID': None,
#   'FILESTATUS': 'N    ',
#   'ATTACHMENTNAME': '2544c9f9-d084-4c36-9deb-b09ac83419a3.pdf',
#   'MORE': 'With reference to the intimation of resignation of Company Secretary namely Ms. Radhika Garg dated 05.08.2024 intimated to BSE on 05.08.2024 at 4:27:40PM, a fresh intimation is being furnished with the letter of resignation, which was missed due to an unintentional and clerical oversight on part of the Company.',
#   'HEADLINE': 'With reference to the intimation of resignation of Company Secretary namely Ms. Radhika Garg dated 05.08.2024 intimated to BSE on 05.08.2024 at 4:27:40PM, a fresh intimation is being furnished ....',
#   'CATEGORYNAME': 'Company Update',
#   'OLD': 1,
#   'RN': 1,
#   'PDFFLAG': 0,
#   'NSURL': 'https://www.bseindia.com/stock-share-price/intec-capital-ltd/inteccap/526871/',
#   'SLONGNAME': 'INTEC CAPITAL LTD.',
#   'AGENDA_ID': 158,
#   'TotalPageCnt': 4,
#   'News_submission_dt': '2024-12-19T14:25:41',
#   'DissemDT': '2024-12-19T14:25:41.333',
#   'TimeDiff': '00:00:00',
#   'Fld_Attachsize': 2808240,
#   'SUBCATNAME': 'Resignation of Company Secretary / Compliance Officer',
#   'AUDIO_VIDEO_FILE': None},
#  {'NEWSID': 'bf1724be-072c-4fcd-a1c7-c9a9fe4a1b65',
#   'SCRIP_CD': 539798,
#   'XML_NAME': 'ANN_539798_BF1724BE-072C-4FCD-A1C7-C9A9FE4A1B65',
#   'NEWSSUB': 'Umiya Tubes Ltd - 539798 - Announcement under Regulation 30 (LODR)-Allotment',
#   'DT_TM': '2024-12-19T14:25:04.01',
#   'NEWS_DT': '2024-12-19T14:25:04.01',
#   'CRITICALNEWS': 0,
#   'ANNOUNCEMENT_TYPE': 'A',
#   'QUARTER_ID': None,
#   'FILESTATUS': 'N    ',
#   'ATTACHMENTNAME': '35f8207a-b8db-4d5e-b5a6-8ecc322ad52d.pdf',
#   'MORE': '',
#   'HEADLINE': 'Allotment of Equity Shares and Convertible Warrants.',
#   'CATEGORYNAME': 'Company Update',
#   'OLD': 1,
#   'RN': 1,
#   'PDFFLAG': 0,
#   'NSURL': 'https://www.bseindia.com/stock-share-price/umiya-tubes-ltd/umiya/539798/',
#   'SLONGNAME': 'Umiya Tubes Ltd',
#   'AGENDA_ID': 5,
#   'TotalPageCnt': 4,
#   'News_submission_dt': '2024-12-19T14:25:03',
#   'DissemDT': '2024-12-19T14:25:04.01',
#   'TimeDiff': '00:00:01',
#   'Fld_Attachsize': 899823,
#   'SUBCATNAME': 'Allotment of Equity Shares',
#   'AUDIO_VIDEO_FILE': None},
#  {'NEWSID': '7da39aaf-077f-4dd6-aa13-a8b7542dcaa8',
#   'SCRIP_CD': 522122,
#   'XML_NAME': 'ANN_522122_7DA39AAF-077F-4DD6-AA13-A8B7542DCAA8',
#   'NEWSSUB': 'VOITH PAPER FABRICS INDIA LTD.-$ - 522122 -  Shareholder Meeting / Postal Ballot-Scrutinizer"s Report',
#   'DT_TM': '2024-12-19T14:21:48.933',
#   'NEWS_DT': '2024-12-19T14:21:48.933',
#   'CRITICALNEWS': 0,
#   'ANNOUNCEMENT_TYPE': 'A',
#   'QUARTER_ID': None,
#   'FILESTATUS': 'N    ',
#   'ATTACHMENTNAME': '2deb3ce8-0134-402b-b812-9fbbb02b8e04.pdf',
#   'MORE': '',
#   'HEADLINE': 'Please find enclosed the result of Postal Ballot exercise, together with the Report of the Scrutinizer.',
#   'CATEGORYNAME': 'AGM/EGM',
#   'OLD': 1,
#   'RN': 1,
#   'PDFFLAG': 0,
#   'NSURL': 'https://www.bseindia.com/stock-share-price/voith-paper-fabrics-india-ltd/voithpapr/522122/',
#   'SLONGNAME': 'VOITH PAPER FABRICS INDIA LTD.-$',
#   'AGENDA_ID': 34,
#   'TotalPageCnt': 4,
#   'News_submission_dt': '2024-12-19T14:21:48',
#   'DissemDT': '2024-12-19T14:21:48.933',
#   'TimeDiff': '00:00:00',
#   'Fld_Attachsize': 894647,
#   'SUBCATNAME': 'Postal Ballot',
#   'AUDIO_VIDEO_FILE': None},
#  {'NEWSID': '15905ff9-9693-4b25-ba9a-4cb461d230f5',
#   'SCRIP_CD': 504286,
#   'XML_NAME': 'ANN_504286_15905FF9-9693-4B25-BA9A-4CB461D230F5',
#   'NEWSSUB': 'Delta Manufacturing Ltd - 504286 - Intimation Of Loss Of Share Certificate',
#   'DT_TM': '2024-12-19T14:18:26.25',
#   'NEWS_DT': '2024-12-19T14:18:26.25',
#   'CRITICALNEWS': 0,
#   'ANNOUNCEMENT_TYPE': 'A',
#   'QUARTER_ID': None,
#   'FILESTATUS': 'N    ',
#   'ATTACHMENTNAME': '02129b65-521a-469e-a1a7-01b02259575f.pdf',
#   'MORE': '',
#   'HEADLINE': 'Intimation of loss of share certificate',
#   'CATEGORYNAME': None,
#   'OLD': 1,
#   'RN': 1,
#   'PDFFLAG': 0,
#   'NSURL': 'https://www.bseindia.com/stock-share-price/delta-manufacturing-ltd/deltamagnt/504286/',
#   'SLONGNAME': 'Delta Manufacturing Ltd',
#   'AGENDA_ID': 177,
#   'TotalPageCnt': 4,
#   'News_submission_dt': '2024-12-19T14:18:26',
#   'DissemDT': '2024-12-19T14:18:26.25',
#   'TimeDiff': '00:00:00',
#   'Fld_Attachsize': 715278,
#   'SUBCATNAME': 'Reg. 39 (3) - Details of Loss of Certificate / Duplicate Certificate',
#   'AUDIO_VIDEO_FILE': None},
#  {'NEWSID': '6024af0c-f874-4981-9431-0f804e2dc2ba',
#   'SCRIP_CD': 530117,
#   'XML_NAME': 'ANN_530117_6024AF0C-F874-4981-9431-0F804E2DC2BA',
#   'NEWSSUB': 'Privi Speciality Chemicals Ltd - 530117 - Compliances-Reg. 39 (3) - Details of Loss of Certificate / Duplicate Certificate',
#   'DT_TM': '2024-12-19T14:15:18.563',
#   'NEWS_DT': '2024-12-19T14:15:18.563',
#   'CRITICALNEWS': 0,
#   'ANNOUNCEMENT_TYPE': 'A',
#   'QUARTER_ID': None,
#   'FILESTATUS': 'N    ',
#   'ATTACHMENTNAME': '1b03d6c8-a459-4766-a504-9fd16626cfa4.pdf',
#   'MORE': '',
#   'HEADLINE': 'Initimation under Reg 39(3) of SEBI (LODR) Regulations, 2015 - Loss of Share Certificate',
#   'CATEGORYNAME': None,
#   'OLD': 1,
#   'RN': 1,
#   'PDFFLAG': 0,
#   'NSURL': 'https://www.bseindia.com/stock-share-price/privi-speciality-chemicals-ltd/priviscl/530117/',
#   'SLONGNAME': 'Privi Speciality Chemicals Ltd',
#   'AGENDA_ID': 177,
#   'TotalPageCnt': 4,
#   'News_submission_dt': '2024-12-19T14:15:18',
#   'DissemDT': '2024-12-19T14:15:18.563',
#   'TimeDiff': '00:00:00',
#   'Fld_Attachsize': 313118,
#   'SUBCATNAME': 'Reg. 39 (3) - Details of Loss of Certificate / Duplicate Certificate',
#   'AUDIO_VIDEO_FILE': None},
#  {'NEWSID': '1e65bd6a-28f2-4458-9b20-d5bb753772a8',
#   'SCRIP_CD': 532822,
#   'XML_NAME': 'ANN_532822_1E65BD6A-28F2-4458-9B20-D5BB753772A8',
#   'NEWSSUB': 'Vodafone Idea Ltd - 532822 - Intimation Pursuant To Regulation 30 Of The SEBI Listing Regulations, 2015',
#   'DT_TM': '2024-12-19T14:14:00.083',
#   'NEWS_DT': '2024-12-19T14:14:00.083',
#   'CRITICALNEWS': 0,
#   'ANNOUNCEMENT_TYPE': 'A',
#   'QUARTER_ID': None,
#   'FILESTATUS': 'N    ',
#   'ATTACHMENTNAME': 'e97736f9-7599-4b30-9e8b-b3c839aa8fff.pdf',
#   'MORE': '',
#   'HEADLINE': 'Disclosure under Regulation 30 of the SEBI (Listing Obligations and Disclosure Requirements) Regulations, 2015',
#   'CATEGORYNAME': 'Company Update',
#   'OLD': 1,
#   'RN': 1,
#   'PDFFLAG': 0,
#   'NSURL': 'https://www.bseindia.com/stock-share-price/vodafone-idea-ltd/idea/532822/',
#   'SLONGNAME': 'Vodafone Idea Ltd',
#   'AGENDA_ID': 1,
#   'TotalPageCnt': 4,
#   'News_submission_dt': '2024-12-19T14:13:59',
#   'DissemDT': '2024-12-19T14:14:00.083',
#   'TimeDiff': '00:00:01',
#   'Fld_Attachsize': 313434,
#   'SUBCATNAME': 'General',
#   'AUDIO_VIDEO_FILE': None},
#  {'NEWSID': 'e13e79bf-4aa3-4408-bf32-9f714001f8aa',
#   'SCRIP_CD': 523309,
#   'XML_NAME': 'ANN_523309_E13E79BF-4AA3-4408-BF32-9F714001F8AA',
#   'NEWSSUB': 'SHRI GANG INDUSTRIES AND ALLIED PRODUCTS LTD. - 523309 - Compliances-Reg. 39 (3) - Details of Loss of Certificate / Duplicate Certificate',
#   'DT_TM': '2024-12-19T14:12:42.26',
#   'NEWS_DT': '2024-12-19T14:12:42.26',
#   'CRITICALNEWS': 0,
#   'ANNOUNCEMENT_TYPE': 'A',
#   'QUARTER_ID': None,
#   'FILESTATUS': 'N    ',
#   'ATTACHMENTNAME': 'c126aaef-c109-41b4-89ce-a5224003f8cb.pdf',
#   'MORE': '',
#   'HEADLINE': 'Intimation',
#   'CATEGORYNAME': None,
#   'OLD': 1,
#   'RN': 1,
#   'PDFFLAG': 0,
#   'NSURL': 'https://www.bseindia.com/stock-share-price/shri-gang-industries-and-allied-products-ltd/shrigang/523309/',
#   'SLONGNAME': 'SHRI GANG INDUSTRIES AND ALLIED PRODUCTS LTD.',
#   'AGENDA_ID': 177,
#   'TotalPageCnt': 4,
#   'News_submission_dt': '2024-12-19T14:12:42',
#   'DissemDT': '2024-12-19T14:12:42.26',
#   'TimeDiff': '00:00:00',
#   'Fld_Attachsize': 830756,
#   'SUBCATNAME': 'Reg. 39 (3) - Details of Loss of Certificate / Duplicate Certificate',
#   'AUDIO_VIDEO_FILE': None},
#  {'NEWSID': '5985f49b-1f78-4c20-ad89-ebe5c6b988bb',
#   'SCRIP_CD': 526521,
#   'XML_NAME': 'ANN_526521_5985F49B-1F78-4C20-AD89-EBE5C6B988BB',
#   'NEWSSUB': 'SANGHI INDUSTRIES LTD. - 526521 - Announcement under Regulation 30 (LODR)-Change in Registered Office Address',
#   'DT_TM': '2024-12-19T14:08:29.523',
#   'NEWS_DT': '2024-12-19T14:08:29.523',
#   'CRITICALNEWS': 0,
#   'ANNOUNCEMENT_TYPE': 'A',
#   'QUARTER_ID': None,
#   'FILESTATUS': 'N    ',
#   'ATTACHMENTNAME': '300f70f1-5170-4487-9cea-c89258f2f865.pdf',
#   'MORE': 'Intimation regarding receipt of Order from Regional Director (South East Region), Ministry of Corporate Affairs, Hyderabad, approving the shifting of Registered Office of the Company from the "State of Telangana" to the "State of Gujarat".',
#   'HEADLINE': 'Intimation regarding receipt of Order from Regional Director (South East Region), Ministry of Corporate Affairs, Hyderabad, approving the shifting of Registered Office of the Company from ....',
#   'CATEGORYNAME': 'Company Update',
#   'OLD': 1,
#   'RN': 1,
#   'PDFFLAG': 0,
#   'NSURL': 'https://www.bseindia.com/stock-share-price/sanghi-industries-ltd/sanghiind/526521/',
#   'SLONGNAME': 'SANGHI INDUSTRIES LTD.',
#   'AGENDA_ID': 153,
#   'TotalPageCnt': 4,
#   'News_submission_dt': '2024-12-19T14:08:29',
#   'DissemDT': '2024-12-19T14:08:29.523',
#   'TimeDiff': '00:00:00',
#   'Fld_Attachsize': 531031,
#   'SUBCATNAME': 'Change in Registered Office Address',
#   'AUDIO_VIDEO_FILE': None},
#  {'NEWSID': '2c1a5097-0087-4804-a0b5-bd1e18372398',
#   'SCRIP_CD': 544283,
#   'XML_NAME': 'ANN_544283_2C1A5097-0087-4804-A0B5-BD1E18372398',
#   'NEWSSUB': 'ACME Solar Holdings Ltd - 544283 - Regulation 30 Of The Securities And Exchange Board Of India (Listing Obligations And Disclosure Requirements) Regulations, 2015',
#   'DT_TM': '2024-12-19T14:06:46.42',
#   'NEWS_DT': '2024-12-19T14:06:46.42',
#   'CRITICALNEWS': 0,
#   'ANNOUNCEMENT_TYPE': 'A',
#   'QUARTER_ID': None,
#   'FILESTATUS': 'N    ',
#   'ATTACHMENTNAME': '1eb8bfdd-7741-411a-ba8d-8d5ccecf8877.pdf',
#   'MORE': '',
#   'HEADLINE': 'Commissioning of aggregate capacity of 1023.05 MW of solar power projects in Rajasthan by wholly owned subsidiaries of ACME Solar Holdings Limited',
#   'CATEGORYNAME': 'Company Update',
#   'OLD': 1,
#   'RN': 1,
#   'PDFFLAG': 0,
#   'NSURL': 'https://www.bseindia.com/stock-share-price/acme-solar-holdings-ltd/acmesolar/544283/',
#   'SLONGNAME': 'ACME Solar Holdings Ltd',
#   'AGENDA_ID': 1,
#   'TotalPageCnt': 4,
#   'News_submission_dt': '2024-12-19T14:06:46',
#   'DissemDT': '2024-12-19T14:06:46.42',
#   'TimeDiff': '00:00:00',
#   'Fld_Attachsize': 181084,
#   'SUBCATNAME': 'General',
#   'AUDIO_VIDEO_FILE': None},
#  {'NEWSID': 'ea726694-9504-470e-a03c-5bc4539188f2',
#   'SCRIP_CD': 541302,
#   'XML_NAME': 'ANN_541302_EA726694-9504-470E-A03C-5BC4539188F2',
#   'NEWSSUB': 'Dhruv Consultancy Services Ltd - 541302 - Announcement under Regulation 30 (LODR)-Change in Management',
#   'DT_TM': '2024-12-19T14:05:44.253',
#   'NEWS_DT': '2024-12-19T14:05:44.253',
#   'CRITICALNEWS': 0,
#   'ANNOUNCEMENT_TYPE': 'A',
#   'QUARTER_ID': None,
#   'FILESTATUS': 'N    ',
#   'ATTACHMENTNAME': '445ef9e0-1789-4370-bd90-3781a7f14be9.pdf',
#   'MORE': '',
#   'HEADLINE': 'appointment of CFO. Detailed letter is attached.',
#   'CATEGORYNAME': 'Company Update',
#   'OLD': 1,
#   'RN': 1,
#   'PDFFLAG': 0,
#   'NSURL': 'https://www.bseindia.com/stock-share-price/dhruv-consultancy-services-ltd/dhruv/541302/',
#   'SLONGNAME': 'Dhruv Consultancy Services Ltd',
#   'AGENDA_ID': 124,
#   'TotalPageCnt': 4,
#   'News_submission_dt': '2024-12-19T14:05:44',
#   'DissemDT': '2024-12-19T14:05:44.253',
#   'TimeDiff': '00:00:00',
#   'Fld_Attachsize': 1983955,
#   'SUBCATNAME': 'Change in Management',
#   'AUDIO_VIDEO_FILE': None},
#  {'NEWSID': 'b39f62be-7686-4c7d-abe9-9e7348162dd3',
#   'SCRIP_CD': 544164,
#   'XML_NAME': 'ANN_544164_B39F62BE-7686-4C7D-ABE9-9E7348162DD3',
#   'NEWSSUB': 'Faalcon Concepts Ltd - 544164 - Postponement Of Extraordinary General Meeting (EGM)',
#   'DT_TM': '2024-12-19T14:05:21.147',
#   'NEWS_DT': '2024-12-19T14:05:21.147',
#   'CRITICALNEWS': 0,
#   'ANNOUNCEMENT_TYPE': 'A',
#   'QUARTER_ID': None,
#   'FILESTATUS': 'N    ',
#   'ATTACHMENTNAME': 'a5c31f44-c06f-43a9-b746-7f46b33bff41.pdf',
#   'MORE': '',
#   'HEADLINE': 'As per file  attached',
#   'CATEGORYNAME': 'Company Update',
#   'OLD': 1,
#   'RN': 1,
#   'PDFFLAG': 0,
#   'NSURL': 'https://www.bseindia.com/stock-share-price/faalcon-concepts-ltd/faalcon/544164/',
#   'SLONGNAME': 'Faalcon Concepts Ltd',
#   'AGENDA_ID': 1,
#   'TotalPageCnt': 4,
#   'News_submission_dt': '2024-12-19T14:05:21',
#   'DissemDT': '2024-12-19T14:05:21.147',
#   'TimeDiff': '00:00:00',
#   'Fld_Attachsize': 670878,
#   'SUBCATNAME': 'General',
#   'AUDIO_VIDEO_FILE': None},
#  {'NEWSID': 'ae995ad6-db13-43f2-bc3b-e7f8b61054b3',
#   'SCRIP_CD': 517063,
#   'XML_NAME': 'ANN_517063_AE995AD6-DB13-43F2-BC3B-E7F8B61054B3',
#   'NEWSSUB': 'JETKING INFOTRAIN LTD. - 517063 -  Shareholder Meeting / Postal Ballot-Scrutinizer"s Report',
#   'DT_TM': '2024-12-19T14:04:50.087',
#   'NEWS_DT': '2024-12-19T14:04:50.087',
#   'CRITICALNEWS': 0,
#   'ANNOUNCEMENT_TYPE': 'A',
#   'QUARTER_ID': None,
#   'FILESTATUS': 'N    ',
#   'ATTACHMENTNAME': 'a3523732-a4db-41e9-9434-9ef4361e3bcb.pdf',
#   'MORE': '',
#   'HEADLINE': 'Report of the scrutinizer dated December 19, 2024 for the postal ballot notice dated November 12, 2024',
#   'CATEGORYNAME': 'AGM/EGM',
#   'OLD': 1,
#   'RN': 1,
#   'PDFFLAG': 0,
#   'NSURL': 'https://www.bseindia.com/stock-share-price/jetking-infotrain-ltd/jetkingq/517063/',
#   'SLONGNAME': 'JETKING INFOTRAIN LTD.',
#   'AGENDA_ID': 34,
#   'TotalPageCnt': 4,
#   'News_submission_dt': '2024-12-19T14:04:49',
#   'DissemDT': '2024-12-19T14:04:50.087',
#   'TimeDiff': '00:00:01',
#   'Fld_Attachsize': 1077578,
#   'SUBCATNAME': 'Postal Ballot',
#   'AUDIO_VIDEO_FILE': None},
#  {'NEWSID': 'fedb0df4-b590-401d-b1f5-a686a5f2b371',
#   'SCRIP_CD': 539056,
#   'XML_NAME': 'ANN_539056_FEDB0DF4-B590-401D-B1F5-A686A5F2B371',
#   'NEWSSUB': 'Imagicaaworld Entertainment Ltd - 539056 - Press Release - Credit Rating',
#   'DT_TM': '2024-12-19T13:59:46.12',
#   'NEWS_DT': '2024-12-19T13:59:46.12',
#   'CRITICALNEWS': 0,
#   'ANNOUNCEMENT_TYPE': 'A',
#   'QUARTER_ID': None,
#   'FILESTATUS': 'N    ',
#   'ATTACHMENTNAME': '1f2ea3b6-0f52-499f-9a53-f912cd17aecd.pdf',
#   'MORE': '',
#   'HEADLINE': 'Please find enclosed the Press Release titled "Imagicaaworld Entertainment Limited rated \'\'IND A\'\' by India Ratings and Research reflecting Financial Resilience"',
#   'CATEGORYNAME': 'Company Update',
#   'OLD': 1,
#   'RN': 1,
#   'PDFFLAG': 0,
#   'NSURL': 'https://www.bseindia.com/stock-share-price/imagicaaworld-entertainment-ltd/imagicaa/539056/',
#   'SLONGNAME': 'Imagicaaworld Entertainment Ltd',
#   'AGENDA_ID': 1,
#   'TotalPageCnt': 4,
#   'News_submission_dt': '2024-12-19T13:59:45',
#   'DissemDT': '2024-12-19T13:59:46.12',
#   'TimeDiff': '00:00:01',
#   'Fld_Attachsize': 511190,
#   'SUBCATNAME': 'General',
#   'AUDIO_VIDEO_FILE': None},
#  {'NEWSID': '2f3478ed-f1a4-43f7-aa8b-3d6910cb277f',
#   'SCRIP_CD': 543651,
#   'XML_NAME': 'ANN_543651_2F3478ED-F1A4-43F7-AA8B-3D6910CB277F',
#   'NEWSSUB': 'DAPS Advertising Ltd - 543651 - RESPONSE TO QUERY OF BSE W.R.T. UNAUDITED FINANCIAL RESULTS FOR HALF YEAR ENDED SEPTEMEBR 2024',
#   'DT_TM': '2024-12-19T13:42:40.143',
#   'NEWS_DT': '2024-12-19T13:42:40.143',
#   'CRITICALNEWS': 0,
#   'ANNOUNCEMENT_TYPE': 'A',
#   'QUARTER_ID': None,
#   'FILESTATUS': 'N    ',
#   'ATTACHMENTNAME': '333d4bc5-c201-4390-879d-d4e744195c2e.pdf',
#   'MORE': 'With reference to email received from BSE seeking bifurcation of Trade Payable in the Unaudited Financial Results of the company, please find attached the company reply along with revised pdf file of Unaudited Financial Results for half year ended Sept., 2024.',
#   'HEADLINE': 'With reference to email received from BSE seeking bifurcation of Trade Payable in the Unaudited Financial Results of the company, please find attached the company reply along with revised ....',
#   'CATEGORYNAME': 'Company Update',
#   'OLD': 1,
#   'RN': 1,
#   'PDFFLAG': 0,
#   'NSURL': 'https://www.bseindia.com/stock-share-price/daps-advertising-ltd/daps/543651/',
#   'SLONGNAME': 'DAPS Advertising Ltd',
#   'AGENDA_ID': 1,
#   'TotalPageCnt': 4,
#   'News_submission_dt': '2024-12-19T13:42:40',
#   'DissemDT': '2024-12-19T13:42:40.143',
#   'TimeDiff': '00:00:00',
#   'Fld_Attachsize': 7664380,
#   'SUBCATNAME': 'General',
#   'AUDIO_VIDEO_FILE': None},
#  {'NEWSID': '7374bf2f-b7dc-4fb7-a66c-6299f7ca2f51',
#   'SCRIP_CD': 541276,
#   'XML_NAME': 'ANN_541276_7374BF2F-B7DC-4FB7-A66C-6299F7CA2F51',
#   'NEWSSUB': 'Hardwyn India Ltd - 541276 - Intimation Of Record Date For The Purpose Of Bonus Shares.',
#   'DT_TM': '2024-12-19T13:36:29.15',
#   'NEWS_DT': '2024-12-19T13:36:29.15',
#   'CRITICALNEWS': 0,
#   'ANNOUNCEMENT_TYPE': 'A',
#   'QUARTER_ID': None,
#   'FILESTATUS': 'N    ',
#   'ATTACHMENTNAME': '55b74e49-5b66-4715-ba0d-c1d06296c4cd.pdf',
#   'MORE': 'In Compliance With Regulation 42 Of The SEBI (Listing Obligations And Disclosure Requirements) Regulations, 2015, The Company Has Fixed Friday, December 27, 2024 As The Record Date For The Purpose Of Determining The Members Eligible For The Issue Of Bonus Equity Shares.',
#   'HEADLINE': 'In Compliance With Regulation 42 Of The SEBI (Listing Obligations And Disclosure Requirements) Regulations, 2015, The Company Has Fixed Friday, December 27, 2024 As The Record Date For ....',
#   'CATEGORYNAME': 'Corp. Action',
#   'OLD': 1,
#   'RN': 1,
#   'PDFFLAG': 0,
#   'NSURL': 'https://www.bseindia.com/stock-share-price/hardwyn-india-ltd/hardwyn/541276/',
#   'SLONGNAME': 'Hardwyn India Ltd',
#   'AGENDA_ID': 36,
#   'TotalPageCnt': 4,
#   'News_submission_dt': '2024-12-19T13:36:29',
#   'DissemDT': '2024-12-19T13:36:29.15',
#   'TimeDiff': '00:00:00',
#   'Fld_Attachsize': 508262,
#   'SUBCATNAME': 'Record Date',
#   'AUDIO_VIDEO_FILE': None},
#  {'NEWSID': '4d2a67af-5d88-494e-9f02-c6792c5b9aff',
#   'SCRIP_CD': 538713,
#   'XML_NAME': 'ANN_538713_4D2A67AF-5D88-494E-9F02-C6792C5B9AFF',
#   'NEWSSUB': 'Atishay Ltd - 538713 - Announcement under Regulation 30 (LODR)-Award_of_Order_Receipt_of_Order',
#   'DT_TM': '2024-12-19T13:33:14.383',
#   'NEWS_DT': '2024-12-19T13:33:14.383',
#   'CRITICALNEWS': 1,
#   'ANNOUNCEMENT_TYPE': 'A',
#   'QUARTER_ID': None,
#   'FILESTATUS': 'N    ',
#   'ATTACHMENTNAME': 'e439f1c9-d918-4699-860d-3dcbddf1357a.pdf',
#   'MORE': 'Atishay Limited has been entrusted with a prestigious work order  for Printing and Delivering of PVC  Ayushman Cards across 14 districts in the state of Haryana from Ayushman Bharat-Haryana Health Protection Authority, with an order  value of Rs. 5.57 Crores.   For more details kindly refer the announcement.',
#   'HEADLINE': 'Atishay Limited has been entrusted with a prestigious work order  for Printing and Delivering of PVC  Ayushman Cards across 14 districts in the state of Haryana from Ayushman Bharat-Haryana ....',
#   'CATEGORYNAME': 'Company Update',
#   'OLD': 1,
#   'RN': 1,
#   'PDFFLAG': 0,
#   'NSURL': 'https://www.bseindia.com/stock-share-price/atishay-ltd/atishay/538713/',
#   'SLONGNAME': 'Atishay Ltd',
#   'AGENDA_ID': 8,
#   'TotalPageCnt': 4,
#   'News_submission_dt': '2024-12-19T13:33:14',
#   'DissemDT': '2024-12-19T13:33:14.383',
#   'TimeDiff': '00:00:00',
#   'Fld_Attachsize': 362375,
#   'SUBCATNAME': 'Award of Order / Receipt of Order',
#   'AUDIO_VIDEO_FILE': None},
#  {'NEWSID': '17babd31-0c25-4e34-a514-d753579c5a7d',
#   'SCRIP_CD': 532872,
#   'XML_NAME': 'ANN_532872_17BABD31-0C25-4E34-A514-D753579C5A7D',
#   'NEWSSUB': 'SUN PHARMA ADVANCED RESEARCH COMPANY LTD. - 532872 - Announcement under Regulation 30 (LODR)-Investor Presentation',
#   'DT_TM': '2024-12-19T13:31:58.11',
#   'NEWS_DT': '2024-12-19T13:31:58.11',
#   'CRITICALNEWS': 0,
#   'ANNOUNCEMENT_TYPE': 'A',
#   'QUARTER_ID': None,
#   'FILESTATUS': 'N    ',
#   'ATTACHMENTNAME': '4d46a667-ac1b-4c57-9637-e3a5976b1443.pdf',
#   'MORE': '',
#   'HEADLINE': 'Investor Presentation - December 2024',
#   'CATEGORYNAME': 'Company Update',
#   'OLD': 1,
#   'RN': 1,
#   'PDFFLAG': 0,
#   'NSURL': 'https://www.bseindia.com/stock-share-price/sun-pharma-advanced-research-company-ltd/sparc/532872/',
#   'SLONGNAME': 'SUN PHARMA ADVANCED RESEARCH COMPANY LTD.',
#   'AGENDA_ID': 120,
#   'TotalPageCnt': 4,
#   'News_submission_dt': '2024-12-19T13:31:57',
#   'DissemDT': '2024-12-19T13:31:58.11',
#   'TimeDiff': '00:00:01',
#   'Fld_Attachsize': 13862618,
#   'SUBCATNAME': 'Investor Presentation',
#   'AUDIO_VIDEO_FILE': None},
#  {'NEWSID': 'f4daf48f-bf78-40e6-be04-1beaa77969cd',
#   'SCRIP_CD': 532902,
#   'XML_NAME': 'ANN_532902_F4DAF48F-BF78-40E6-BE04-1BEAA77969CD',
#   'NEWSSUB': 'CONSOLIDATED CONSTRUCTION CONSORTIUM LTD. - 532902 - Announcement under Regulation 30 (LODR)-Resignation of Company Secretary / Compliance Officer',
#   'DT_TM': '2024-12-19T13:30:47.237',
#   'NEWS_DT': '2024-12-19T13:30:47.237',
#   'CRITICALNEWS': 0,
#   'ANNOUNCEMENT_TYPE': 'A',
#   'QUARTER_ID': None,
#   'FILESTATUS': 'N    ',
#   'ATTACHMENTNAME': '8498b933-ad5e-429d-9c8e-daea0d2a6468.pdf',
#   'MORE': 'Resignation of  Mr. Niranjan Chandrashekar  from the post of Company Secretary & Compliance Officer- with effect from 19th December 2024 and Appointment of Mr. S.S. Arunachalam as a Compliance Officer with effect from 20th December 2024.',
#   'HEADLINE': 'Resignation of  Mr. Niranjan Chandrashekar  from the post of Company Secretary & Compliance Officer- with effect from 19th December 2024 and Appointment of Mr. S.S. Arunachalam as a Compliance ....',
#   'CATEGORYNAME': 'Company Update',
#   'OLD': 1,
#   'RN': 1,
#   'PDFFLAG': 0,
#   'NSURL': 'https://www.bseindia.com/stock-share-price/consolidated-construction-consortium-ltd/cccl/532902/',
#   'SLONGNAME': 'CONSOLIDATED CONSTRUCTION CONSORTIUM LTD.',
#   'AGENDA_ID': 158,
#   'TotalPageCnt': 4,
#   'News_submission_dt': '2024-12-19T13:30:47',
#   'DissemDT': '2024-12-19T13:30:47.237',
#   'TimeDiff': '00:00:00',
#   'Fld_Attachsize': 1394714,
#   'SUBCATNAME': 'Resignation of Company Secretary / Compliance Officer',
#   'AUDIO_VIDEO_FILE': None},
#  {'NEWSID': '686563ac-6e7d-4abc-a1a2-765bf43f06c7',
#   'SCRIP_CD': 530589,
#   'XML_NAME': 'ANN_530589_686563AC-6E7D-4ABC-A1A2-765BF43F06C7',
#   'NEWSSUB': 'PRIMA PLASTICS LTD. - 530589 - Intimation Under Regulation 30 Of SEBI (LODR), Regulations 2015 - Capacity Addition',
#   'DT_TM': '2024-12-19T13:26:09.417',
#   'NEWS_DT': '2024-12-19T13:26:09.417',
#   'CRITICALNEWS': 0,
#   'ANNOUNCEMENT_TYPE': 'A',
#   'QUARTER_ID': None,
#   'FILESTATUS': 'N    ',
#   'ATTACHMENTNAME': 'b6906b21-38a8-4622-8b2e-88a12ba0ee3e.pdf',
#   'MORE': '',
#   'HEADLINE': 'We are pleased to inform that the production capacity of Prima Union Plasticos S.A., Subsidiary of the company located at Guatemala has increased. The details are provided herewith.',
#   'CATEGORYNAME': 'Company Update',
#   'OLD': 1,
#   'RN': 1,
#   'PDFFLAG': 0,
#   'NSURL': 'https://www.bseindia.com/stock-share-price/prima-plastics-ltd/primapla/530589/',
#   'SLONGNAME': 'PRIMA PLASTICS LTD.',
#   'AGENDA_ID': 1,
#   'TotalPageCnt': 4,
#   'News_submission_dt': '2024-12-19T13:26:09',
#   'DissemDT': '2024-12-19T13:26:09.417',
#   'TimeDiff': '00:00:00',
#   'Fld_Attachsize': 566896,
#   'SUBCATNAME': 'General',
#   'AUDIO_VIDEO_FILE': None},
#  {'NEWSID': '3a05b92b-810f-428e-a491-52c10ec92e23',
#   'SCRIP_CD': 544305,
#   'XML_NAME': 'ANN_544305_3A05B92B-810F-428E-A491-52C10EC92E23',
#   'NEWSSUB': 'One Mobikwik Systems Ltd - 544305 - Closure of Trading Window',
#   'DT_TM': '2024-12-19T13:22:23.717',
#   'NEWS_DT': '2024-12-19T13:22:23.717',
#   'CRITICALNEWS': 0,
#   'ANNOUNCEMENT_TYPE': 'A',
#   'QUARTER_ID': None,
#   'FILESTATUS': 'N    ',
#   'ATTACHMENTNAME': '6cc19a94-c6ae-42a2-b5ba-33bc3fea328d.pdf',
#   'MORE': '',
#   'HEADLINE': 'Intimation regarding the trading window closure pursuant to SEBI (Prohibition of Insider Trading) Regulations, 2015',
#   'CATEGORYNAME': 'Insider Trading / SAST',
#   'OLD': 1,
#   'RN': 1,
#   'PDFFLAG': 0,
#   'NSURL': 'https://www.bseindia.com/stock-share-price/one-mobikwik-systems-ltd/mobikwik/544305/',
#   'SLONGNAME': 'One Mobikwik Systems Ltd',
#   'AGENDA_ID': 66,
#   'TotalPageCnt': 4,
#   'News_submission_dt': '2024-12-19T13:22:23',
#   'DissemDT': '2024-12-19T13:22:23.717',
#   'TimeDiff': '00:00:00',
#   'Fld_Attachsize': 612956,
#   'SUBCATNAME': 'Closure of Trading Window',
#   'AUDIO_VIDEO_FILE': None},
#  {'NEWSID': '38db3ae2-7527-42a0-ad0d-6f200075c005',
#   'SCRIP_CD': 500060,
#   'XML_NAME': 'ANN_500060_38DB3AE2-7527-42A0-AD0D-6F200075C005',
#   'NEWSSUB': 'Birla Cable Ltd - 500060 - Compliances-Reg. 39 (3) - Details of Loss of Certificate / Duplicate Certificate',
#   'DT_TM': '2024-12-19T13:10:34.727',
#   'NEWS_DT': '2024-12-19T13:10:34.727',
#   'CRITICALNEWS': 0,
#   'ANNOUNCEMENT_TYPE': 'A',
#   'QUARTER_ID': None,
#   'FILESTATUS': 'N    ',
#   'ATTACHMENTNAME': '5c258ea7-1034-406a-a7fe-15d1de7abb32.pdf',
#   'MORE': '',
#   'HEADLINE': 'Intimation regarding issuance of duplicate share certificates due to Loss of Original Share Certificates under Regulation 39(3) of the SEBI(LODR) Regulations,2015.',
#   'CATEGORYNAME': None,
#   'OLD': 1,
#   'RN': 1,
#   'PDFFLAG': 0,
#   'NSURL': 'https://www.bseindia.com/stock-share-price/birla-cable-ltd/birlacable/500060/',
#   'SLONGNAME': 'Birla Cable Ltd',
#   'AGENDA_ID': 177,
#   'TotalPageCnt': 4,
#   'News_submission_dt': '2024-12-19T13:10:34',
#   'DissemDT': '2024-12-19T13:10:34.727',
#   'TimeDiff': '00:00:00',
#   'Fld_Attachsize': 522518,
#   'SUBCATNAME': 'Reg. 39 (3) - Details of Loss of Certificate / Duplicate Certificate',
#   'AUDIO_VIDEO_FILE': None},
#  {'NEWSID': '28cf695c-2a34-4b19-afc4-a83923fe49dc',
#   'SCRIP_CD': 532894,
#   'XML_NAME': 'ANN_532894_28CF695C-2A34-4B19-AFC4-A83923FE49DC',
#   'NEWSSUB': 'INDOWIND ENERGY LTD. - 532894 - Shareholder Meeting / Postal Ballot-Notice of Postal Ballot',
#   'DT_TM': '2024-12-19T13:10:33.12',
#   'NEWS_DT': '2024-12-19T13:10:33.12',
#   'CRITICALNEWS': 0,
#   'ANNOUNCEMENT_TYPE': 'A',
#   'QUARTER_ID': None,
#   'FILESTATUS': 'N    ',
#   'ATTACHMENTNAME': '01450dd4-ea1a-44c5-b4b7-a9d8440d9457.pdf',
#   'MORE': '',
#   'HEADLINE': 'Dear sir/madam,\r\nPFA Postal Ballot Notice.',
#   'CATEGORYNAME': 'AGM/EGM',
#   'OLD': 1,
#   'RN': 1,
#   'PDFFLAG': 0,
#   'NSURL': 'https://www.bseindia.com/stock-share-price/indowind-energy-ltd/indowind/532894/',
#   'SLONGNAME': 'INDOWIND ENERGY LTD.',
#   'AGENDA_ID': 34,
#   'TotalPageCnt': 4,
#   'News_submission_dt': '2024-12-19T13:10:32',
#   'DissemDT': '2024-12-19T13:10:33.12',
#   'TimeDiff': '00:00:01',
#   'Fld_Attachsize': 1611841,
#   'SUBCATNAME': 'Postal Ballot',
#   'AUDIO_VIDEO_FILE': None},
#  {'NEWSID': '456a9cd3-d7e7-4651-9f3b-8de693de0d7c',
#   'SCRIP_CD': 530259,
#   'XML_NAME': 'ANN_530259_456A9CD3-D7E7-4651-9F3B-8DE693DE0D7C',
#   'NEWSSUB': 'INTER STATE OIL CARRIER LTD. - 530259 - Closure of Trading Window',
#   'DT_TM': '2024-12-19T13:10:29.237',
#   'NEWS_DT': '2024-12-19T13:10:29.237',
#   'CRITICALNEWS': 0,
#   'ANNOUNCEMENT_TYPE': 'A',
#   'QUARTER_ID': None,
#   'FILESTATUS': 'N    ',
#   'ATTACHMENTNAME': 'e13d980f-f0a8-4a26-8d7c-949be4dcfd46.pdf',
#   'MORE': '',
#   'HEADLINE': 'Closure of Trading Window.',
#   'CATEGORYNAME': 'Insider Trading / SAST',
#   'OLD': 1,
#   'RN': 1,
#   'PDFFLAG': 0,
#   'NSURL': 'https://www.bseindia.com/stock-share-price/inter-state-oil-carrier-ltd/intstoil/530259/',
#   'SLONGNAME': 'INTER STATE OIL CARRIER LTD.',
#   'AGENDA_ID': 66,
#   'TotalPageCnt': 4,
#   'News_submission_dt': '2024-12-19T13:10:29',
#   'DissemDT': '2024-12-19T13:10:29.237',
#   'TimeDiff': '00:00:00',
#   'Fld_Attachsize': 255367,
#   'SUBCATNAME': 'Closure of Trading Window',
#   'AUDIO_VIDEO_FILE': None},
#  {'NEWSID': '34771513-a154-40bc-8d8a-97aefb0ba100',
#   'SCRIP_CD': 519091,
#   'XML_NAME': 'ANN_519091_34771513-A154-40BC-8D8A-97AEFB0BA100',
#   'NEWSSUB': 'TASTY BITE EATABLES LTD. - 519091 - Announcement under Regulation 30 (LODR)-Resignation of Director',
#   'DT_TM': '2024-12-19T13:08:27.92',
#   'NEWS_DT': '2024-12-19T13:08:27.92',
#   'CRITICALNEWS': 0,
#   'ANNOUNCEMENT_TYPE': 'A',
#   'QUARTER_ID': None,
#   'FILESTATUS': 'N    ',
#   'ATTACHMENTNAME': 'ebe7b596-7dd9-4934-b55c-f21755fd267e.pdf',
#   'MORE': '',
#   'HEADLINE': 'Intimation of Resignation of Mr. Chengappa Ganapati (DIN: 06771287) as the Independent Director of the Company.',
#   'CATEGORYNAME': 'Company Update',
#   'OLD': 1,
#   'RN': 1,
#   'PDFFLAG': 0,
#   'NSURL': 'https://www.bseindia.com/stock-share-price/tasty-bite-eatables-ltd/tastybite/519091/',
#   'SLONGNAME': 'TASTY BITE EATABLES LTD.',
#   'AGENDA_ID': 102,
#   'TotalPageCnt': 4,
#   'News_submission_dt': '2024-12-19T13:08:27',
#   'DissemDT': '2024-12-19T13:08:27.92',
#   'TimeDiff': '00:00:00',
#   'Fld_Attachsize': 779946,
#   'SUBCATNAME': 'Resignation of Director',
#   'AUDIO_VIDEO_FILE': None},
#  {'NEWSID': 'fdfa4f73-8123-4555-a26d-4b91470b708a',
#   'SCRIP_CD': 526817,
#   'XML_NAME': 'ANN_526817_FDFA4F73-8123-4555-A26D-4B91470B708A',
#   'NEWSSUB': 'CHEVIOT CO.LTD.-$ - 526817 - Closure of Trading Window',
#   'DT_TM': '2024-12-19T13:07:22.697',
#   'NEWS_DT': '2024-12-19T13:07:22.697',
#   'CRITICALNEWS': 0,
#   'ANNOUNCEMENT_TYPE': 'A',
#   'QUARTER_ID': None,
#   'FILESTATUS': 'N    ',
#   'ATTACHMENTNAME': '293020a5-93cc-4082-b6f6-923c6667c1e6.pdf',
#   'MORE': '',
#   'HEADLINE': 'Closure of Trading Window pursuant to SEBI (Prohibition of Insider Trading) Regulations, 2015',
#   'CATEGORYNAME': 'Insider Trading / SAST',
#   'OLD': 1,
#   'RN': 1,
#   'PDFFLAG': 0,
#   'NSURL': 'https://www.bseindia.com/stock-share-price/cheviot-coltd/cheviot/526817/',
#   'SLONGNAME': 'CHEVIOT CO.LTD.-$',
#   'AGENDA_ID': 66,
#   'TotalPageCnt': 4,
#   'News_submission_dt': '2024-12-19T13:07:22',
#   'DissemDT': '2024-12-19T13:07:22.697',
#   'TimeDiff': '00:00:00',
#   'Fld_Attachsize': 169512,
#   'SUBCATNAME': 'Closure of Trading Window',
#   'AUDIO_VIDEO_FILE': None},
#  {'NEWSID': '0b698e17-f729-4302-846e-79583c8d8757',
#   'SCRIP_CD': 530427,
#   'XML_NAME': 'ANN_530427_0B698E17-F729-4302-846E-79583C8D8757',
#   'NEWSSUB': 'CHOKSI IMAGING LTD. - 530427 - Shareholder Meeting / Postal Ballot-Notice of Postal Ballot',
#   'DT_TM': '2024-12-19T13:03:10.697',
#   'NEWS_DT': '2024-12-19T13:03:10.697',
#   'CRITICALNEWS': 0,
#   'ANNOUNCEMENT_TYPE': 'A',
#   'QUARTER_ID': None,
#   'FILESTATUS': 'N    ',
#   'ATTACHMENTNAME': '2dc92afe-c571-49ad-92ba-d016e6ea55d7.pdf',
#   'MORE': '',
#   'HEADLINE': 'Notice of Postal Ballot for appointment of Independent Director.',
#   'CATEGORYNAME': 'AGM/EGM',
#   'OLD': 1,
#   'RN': 1,
#   'PDFFLAG': 0,
#   'NSURL': 'https://www.bseindia.com/stock-share-price/choksi-imaging-ltd/choksi/530427/',
#   'SLONGNAME': 'CHOKSI IMAGING LTD.',
#   'AGENDA_ID': 34,
#   'TotalPageCnt': 4,
#   'News_submission_dt': '2024-12-19T13:03:10',
#   'DissemDT': '2024-12-19T13:03:10.697',
#   'TimeDiff': '00:00:00',
#   'Fld_Attachsize': 313382,
#   'SUBCATNAME': 'Postal Ballot',
#   'AUDIO_VIDEO_FILE': None},
#  {'NEWSID': 'bc0fa221-e5a1-4318-bf18-1833f29045dc',
#   'SCRIP_CD': 504605,
#   'XML_NAME': 'ANN_504605_BC0FA221-E5A1-4318-BF18-1833F29045DC',
#   'NEWSSUB': 'UNI ABEX ALLOY PRODUCTS LTD. - 504605 - Announcement under Regulation 30 (LODR)-Newspaper Publication',
#   'DT_TM': '2024-12-19T13:01:04.673',
#   'NEWS_DT': '2024-12-19T13:01:04.673',
#   'CRITICALNEWS': 0,
#   'ANNOUNCEMENT_TYPE': 'A',
#   'QUARTER_ID': None,
#   'FILESTATUS': 'N    ',
#   'ATTACHMENTNAME': '01111a4b-08bf-48a5-ae23-50f8f266eb9b.pdf',
#   'MORE': '',
#   'HEADLINE': 'Newspaper Advertisement of Postal Ballot Notice',
#   'CATEGORYNAME': 'Company Update',
#   'OLD': 1,
#   'RN': 1,
#   'PDFFLAG': 0,
#   'NSURL': 'https://www.bseindia.com/stock-share-price/uni-abex-alloy-products-ltd/uniabexal/504605/',
#   'SLONGNAME': 'UNI ABEX ALLOY PRODUCTS LTD.',
#   'AGENDA_ID': 144,
#   'TotalPageCnt': 4,
#   'News_submission_dt': '2024-12-19T13:01:04',
#   'DissemDT': '2024-12-19T13:01:04.673',
#   'TimeDiff': '00:00:00',
#   'Fld_Attachsize': 8211426,
#   'SUBCATNAME': 'Newspaper Publication',
#   'AUDIO_VIDEO_FILE': None},
#  {'NEWSID': 'b47a2ddd-2dd6-4535-b92b-ae67e3238548',
#   'SCRIP_CD': 532430,
#   'XML_NAME': 'ANN_532430_B47A2DDD-2DD6-4535-B92B-AE67E3238548',
#   'NEWSSUB': 'BF UTILITIES LTD.-$ - 532430 - Compliances-Reg. 39 (3) - Details of Loss of Certificate / Duplicate Certificate',
#   'DT_TM': '2024-12-19T13:01:02.183',
#   'NEWS_DT': '2024-12-19T13:01:02.183',
#   'CRITICALNEWS': 0,
#   'ANNOUNCEMENT_TYPE': 'A',
#   'QUARTER_ID': None,
#   'FILESTATUS': 'N    ',
#   'ATTACHMENTNAME': 'b25704b3-f73f-4ba7-8ca3-bc2bace06cf6.pdf',
#   'MORE': '',
#   'HEADLINE': 'Intimation of Loss of Share Certificate(s)',
#   'CATEGORYNAME': None,
#   'OLD': 1,
#   'RN': 1,
#   'PDFFLAG': 0,
#   'NSURL': 'https://www.bseindia.com/stock-share-price/bf-utilities-ltd/bfutilitie/532430/',
#   'SLONGNAME': 'BF UTILITIES LTD.-$',
#   'AGENDA_ID': 177,
#   'TotalPageCnt': 4,
#   'News_submission_dt': '2024-12-19T13:01:02',
#   'DissemDT': '2024-12-19T13:01:02.183',
#   'TimeDiff': '00:00:00',
#   'Fld_Attachsize': 205757,
#   'SUBCATNAME': 'Reg. 39 (3) - Details of Loss of Certificate / Duplicate Certificate',
#   'AUDIO_VIDEO_FILE': None},
#  {'NEWSID': 'd85a00c5-993d-4190-94a3-38dfbf93f5cc',
#   'SCRIP_CD': 532402,
#   'XML_NAME': 'ANN_532402_D85A00C5-993D-4190-94A3-38DFBF93F5CC',
#   'NEWSSUB': 'USG TECH SOLUTIONS LTD. - 532402 - Board Meeting Intimation for The Meeting Of Board Of Directors To Be Held On Friday, 27Th December, 2024 At 11:00 AM.',
#   'DT_TM': '2024-12-19T12:58:59.747',
#   'NEWS_DT': '2024-12-19T12:58:59.747',
#   'CRITICALNEWS': 1,
#   'ANNOUNCEMENT_TYPE': 'A',
#   'QUARTER_ID': None,
#   'FILESTATUS': 'N    ',
#   'ATTACHMENTNAME': 'c0bea2c5-b7c3-471d-8110-f995ecaa70c7.pdf',
#   'MORE': 'USG TECH SOLUTIONS LTD.has informed BSE that the meeting of the Board of Directors of the Company is scheduled on 27/12/2024 ,inter alia, to consider and approve the agenda items as per the attached pdf.',
#   'HEADLINE': 'USG TECH SOLUTIONS LTD.has informed BSE that the meeting of the Board of Directors of the Company is scheduled on 27/12/2024 ,inter alia, to consider and approve the agenda items as per ....',
#   'CATEGORYNAME': 'Board Meeting',
#   'OLD': 1,
#   'RN': 1,
#   'PDFFLAG': 0,
#   'NSURL': 'https://www.bseindia.com/stock-share-price/usg-tech-solutions-ltd/usgtech/532402/',
#   'SLONGNAME': 'USG TECH SOLUTIONS LTD.',
#   'AGENDA_ID': 9,
#   'TotalPageCnt': 4,
#   'News_submission_dt': '2024-12-19T12:58:58',
#   'DissemDT': '2024-12-19T12:58:59.747',
#   'TimeDiff': '00:00:01',
#   'Fld_Attachsize': 290921,
#   'SUBCATNAME': 'Board Meeting',
#   'AUDIO_VIDEO_FILE': None},
#  {'NEWSID': 'e6cd276c-da9b-48d8-a37d-8b10a6c1b86b',
#   'SCRIP_CD': 532734,
#   'XML_NAME': 'ANN_532734_E6CD276C-DA9B-48D8-A37D-8B10A6C1B86B',
#   'NEWSSUB': 'GODAWARI POWER & ISPAT LTD. - 532734 - Announcement under Regulation 30 (LODR)-Credit Rating',
#   'DT_TM': '2024-12-19T12:58:13.57',
#   'NEWS_DT': '2024-12-19T12:58:13.57',
#   'CRITICALNEWS': 1,
#   'ANNOUNCEMENT_TYPE': 'A',
#   'QUARTER_ID': None,
#   'FILESTATUS': 'N    ',
#   'ATTACHMENTNAME': 'b30cfefe-8660-4c67-82ff-fe9ba6b12b58.pdf',
#   'MORE': '',
#   'HEADLINE': 'Please find attached herewith letter dated 19.12.2024 pertaining to credit rating of the Company.',
#   'CATEGORYNAME': 'Company Update',
#   'OLD': 1,
#   'RN': 1,
#   'PDFFLAG': 0,
#   'NSURL': 'https://www.bseindia.com/stock-share-price/godawari-power--ispat-ltd/gpil/532734/',
#   'SLONGNAME': 'GODAWARI POWER & ISPAT LTD.',
#   'AGENDA_ID': 46,
#   'TotalPageCnt': 4,
#   'News_submission_dt': '2024-12-19T12:58:13',
#   'DissemDT': '2024-12-19T12:58:13.57',
#   'TimeDiff': '00:00:00',
#   'Fld_Attachsize': 469244,
#   'SUBCATNAME': 'Credit Rating',
#   'AUDIO_VIDEO_FILE': None},
#  {'NEWSID': '9661e48b-5b16-44cb-a2b3-14382cbcb939',
#   'SCRIP_CD': 523411,
#   'XML_NAME': 'ANN_523411_9661E48B-5B16-44CB-A2B3-14382CBCB939',
#   'NEWSSUB': 'ADC India Communications Limited-$ - 523411 - Compliances-Reg. 39 (3) - Details of Loss of Certificate / Duplicate Certificate',
#   'DT_TM': '2024-12-19T12:57:33.743',
#   'NEWS_DT': '2024-12-19T12:57:33.743',
#   'CRITICALNEWS': 0,
#   'ANNOUNCEMENT_TYPE': 'A',
#   'QUARTER_ID': None,
#   'FILESTATUS': 'N    ',
#   'ATTACHMENTNAME': '48ca6a95-4974-4a6b-8d28-f4b3aebf4cdd.pdf',
#   'MORE': '',
#   'HEADLINE': 'Intimation of Loss of Share Certificate',
#   'CATEGORYNAME': None,
#   'OLD': 1,
#   'RN': 1,
#   'PDFFLAG': 0,
#   'NSURL': 'https://www.bseindia.com/stock-share-price/adc-india-communications-limited/adcindia/523411/',
#   'SLONGNAME': 'ADC India Communications Limited-$',
#   'AGENDA_ID': 177,
#   'TotalPageCnt': 4,
#   'News_submission_dt': '2024-12-19T12:57:33',
#   'DissemDT': '2024-12-19T12:57:33.743',
#   'TimeDiff': '00:00:00',
#   'Fld_Attachsize': 847261,
#   'SUBCATNAME': 'Reg. 39 (3) - Details of Loss of Certificate / Duplicate Certificate',
#   'AUDIO_VIDEO_FILE': None},
#  {'NEWSID': '1919aa95-9180-4ac0-a49c-b03a3d5c0486',
#   'SCRIP_CD': 543767,
#   'XML_NAME': 'ANN_543767_1919AA95-9180-4AC0-A49C-B03A3D5C0486',
#   'NEWSSUB': 'Bodhi Tree Multimedia Ltd - 543767 - Announcement under Regulation 30 (LODR)-Press Release / Media Release',
#   'DT_TM': '2024-12-19T12:57:33.32',
#   'NEWS_DT': '2024-12-19T12:57:33.32',
#   'CRITICALNEWS': 0,
#   'ANNOUNCEMENT_TYPE': 'A',
#   'QUARTER_ID': None,
#   'FILESTATUS': 'N    ',
#   'ATTACHMENTNAME': 'db050270-1aa5-4fdd-8115-2b0f618ad84f.pdf',
#   'MORE': '',
#   'HEADLINE': 'Press Release on Colors Marathi and Bodhitree Multimedia New Marathi Drama \'\'Ashok Ma.Ma"',
#   'CATEGORYNAME': 'Company Update',
#   'OLD': 1,
#   'RN': 1,
#   'PDFFLAG': 0,
#   'NSURL': 'https://www.bseindia.com/stock-share-price/bodhi-tree-multimedia-ltd/btml/543767/',
#   'SLONGNAME': 'Bodhi Tree Multimedia Ltd',
#   'AGENDA_ID': 35,
#   'TotalPageCnt': 4,
#   'News_submission_dt': '2024-12-19T12:57:33',
#   'DissemDT': '2024-12-19T12:57:33.32',
#   'TimeDiff': '00:00:00',
#   'Fld_Attachsize': 2928431,
#   'SUBCATNAME': 'Press Release / Media Release',
#   'AUDIO_VIDEO_FILE': None},
#  {'NEWSID': '0ad2ef56-1fcd-4195-82e4-13b2726edce3',
#   'SCRIP_CD': 542724,
#   'XML_NAME': 'ANN_542724_0AD2EF56-1FCD-4195-82E4-13B2726EDCE3',
#   'NEWSSUB': "Murae Organisor Ltd - 542724 - Notice Of Extra-Ordinary General Meeting ('EGM') Of The Company",
#   'DT_TM': '2024-12-19T12:55:55.76',
#   'NEWS_DT': '2024-12-19T12:55:55.76',
#   'CRITICALNEWS': 1,
#   'ANNOUNCEMENT_TYPE': 'A',
#   'QUARTER_ID': None,
#   'FILESTATUS': 'N    ',
#   'ATTACHMENTNAME': '8889be7a-3b25-4718-ab37-6261cda561e2.pdf',
#   'MORE': '',
#   'HEADLINE': 'Notice of EGM is attached herewith.',
#   'CATEGORYNAME': 'AGM/EGM',
#   'OLD': 1,
#   'RN': 1,
#   'PDFFLAG': 0,
#   'NSURL': 'https://www.bseindia.com/stock-share-price/murae-organisor-ltd/murae/542724/',
#   'SLONGNAME': 'Murae Organisor Ltd',
#   'AGENDA_ID': 28,
#   'TotalPageCnt': 4,
#   'News_submission_dt': '2024-12-19T12:55:55',
#   'DissemDT': '2024-12-19T12:55:55.76',
#   'TimeDiff': '00:00:00',
#   'Fld_Attachsize': 1028826,
#   'SUBCATNAME': 'EGM',
#   'AUDIO_VIDEO_FILE': None},
#  {'NEWSID': 'b1b5213c-a3aa-46a0-bdf9-72c1bf7efadd',
#   'SCRIP_CD': 512068,
#   'XML_NAME': 'ANN_512068_B1B5213C-A3AA-46A0-BDF9-72C1BF7EFADD',
#   'NEWSSUB': "DECCAN GOLD MINES LTD. - 512068 - Disclosure Under Regulation 30 Of SEBI (Listing Obligations & Disclosure Requirements) Regulations, 2015 - Update On Altyn Tor Gold Project Of Avelum Partners LLC, Republic Of Kyrgyzstan ('Avelum'), Our Subsidiary Company",
#   'DT_TM': '2024-12-19T12:54:05.413',
#   'NEWS_DT': '2024-12-19T12:54:05.413',
#   'CRITICALNEWS': 0,
#   'ANNOUNCEMENT_TYPE': 'A',
#   'QUARTER_ID': None,
#   'FILESTATUS': 'N    ',
#   'ATTACHMENTNAME': '8440d5e9-cf29-45bb-98bb-aef8fd58d6f6.pdf',
#   'MORE': 'Disclosure under Regulation 30 of SEBI (Listing Obligations & Disclosure Requirements) Regulations, 2015- Update on Altyn Tor Gold Project of Avelum Partners LLC, Republic of Kyrgyzstan ("Avelum"), our Subsidiary Company.',
#   'HEADLINE': 'Disclosure under Regulation 30 of SEBI (Listing Obligations & Disclosure Requirements) Regulations, 2015- Update on Altyn Tor Gold Project of Avelum Partners LLC, Republic of Kyrgyzstan ....',
#   'CATEGORYNAME': 'Company Update',
#   'OLD': 1,
#   'RN': 1,
#   'PDFFLAG': 0,
#   'NSURL': 'https://www.bseindia.com/stock-share-price/deccan-gold-mines-ltd/decngold/512068/',
#   'SLONGNAME': 'DECCAN GOLD MINES LTD.',
#   'AGENDA_ID': 1,
#   'TotalPageCnt': 4,
#   'News_submission_dt': '2024-12-19T12:54:05',
#   'DissemDT': '2024-12-19T12:54:05.413',
#   'TimeDiff': '00:00:00',
#   'Fld_Attachsize': 456079,
#   'SUBCATNAME': 'General',
#   'AUDIO_VIDEO_FILE': None},
#  {'NEWSID': '09c8b654-03f6-4455-90ad-5fdb9631a53f',
#   'SCRIP_CD': 500338,
#   'XML_NAME': 'ANN_500338_09C8B654-03F6-4455-90AD-5FDB9631A53F',
#   'NEWSSUB': 'Prism Johnson Ltd - 500338 - Announcement under Regulation 30 (LODR)-Press Release / Media Release',
#   'DT_TM': '2024-12-19T12:50:18.097',
#   'NEWS_DT': '2024-12-19T12:50:18.097',
#   'CRITICALNEWS': 0,
#   'ANNOUNCEMENT_TYPE': 'A',
#   'QUARTER_ID': None,
#   'FILESTATUS': 'N    ',
#   'ATTACHMENTNAME': '64fb2d72-57d1-40f5-b691-2b44653d7b0b.pdf',
#   'MORE': '',
#   'HEADLINE': 'Please find attached Media Release proposed to be issued by the Company titled "Prism Johnson Limited, Cement Business Division Goes Live with RAMCO ERP."',
#   'CATEGORYNAME': 'Company Update',
#   'OLD': 1,
#   'RN': 1,
#   'PDFFLAG': 0,
#   'NSURL': 'https://www.bseindia.com/stock-share-price/prism-johnson-ltd/prsmjohnsn/500338/',
#   'SLONGNAME': 'Prism Johnson Ltd',
#   'AGENDA_ID': 35,
#   'TotalPageCnt': 4,
#   'News_submission_dt': '2024-12-19T12:50:17',
#   'DissemDT': '2024-12-19T12:50:18.097',
#   'TimeDiff': '00:00:01',
#   'Fld_Attachsize': 391434,
#   'SUBCATNAME': 'Press Release / Media Release',
#   'AUDIO_VIDEO_FILE': None},
#  {'NEWSID': 'd2339b5b-a0f9-491e-bf0d-a93acb576e43',
#   'SCRIP_CD': 543986,
#   'XML_NAME': 'ANN_543986_D2339B5B-A0F9-491E-BF0D-A93ACB576E43',
#   'NEWSSUB': 'South West Pinnacle Exploration Ltd - 543986 - Announcement under Regulation 30 (LODR)-Press Release / Media Release',
#   'DT_TM': '2024-12-19T12:48:53.37',
#   'NEWS_DT': '2024-12-19T12:48:53.37',
#   'CRITICALNEWS': 0,
#   'ANNOUNCEMENT_TYPE': 'A',
#   'QUARTER_ID': None,
#   'FILESTATUS': 'N    ',
#   'ATTACHMENTNAME': '4d01eed1-3bc0-4945-aa4b-9f96b32021d4.pdf',
#   'MORE': '',
#   'HEADLINE': 'Company wins Letter of Award for Imparting services of Passive Seismic Tomography(PST)  from Oil India Limited aggregated value of ~Rs.60 Crores.',
#   'CATEGORYNAME': 'Company Update',
#   'OLD': 1,
#   'RN': 1,
#   'PDFFLAG': 0,
#   'NSURL': 'https://www.bseindia.com/stock-share-price/south-west-pinnacle-exploration-ltd/southwest/543986/',
#   'SLONGNAME': 'South West Pinnacle Exploration Ltd',
#   'AGENDA_ID': 35,
#   'TotalPageCnt': 4,
#   'News_submission_dt': '2024-12-19T12:48:53',
#   'DissemDT': '2024-12-19T12:48:53.37',
#   'TimeDiff': '00:00:00',
#   'Fld_Attachsize': 449633,
#   'SUBCATNAME': 'Press Release / Media Release',
#   'AUDIO_VIDEO_FILE': None},
#  {'NEWSID': '31923ea1-17db-420f-abef-663f2f1f79c4',
#   'SCRIP_CD': 531373,
#   'XML_NAME': 'ANN_531373_31923EA1-17DB-420F-ABEF-663F2F1F79C4',
#   'NEWSSUB': 'THE BYKE HOSPITALITY LTD. - 531373 - Compliances-Reg. 39 (3) - Details of Loss of Certificate / Duplicate Certificate',
#   'DT_TM': '2024-12-19T12:47:00.107',
#   'NEWS_DT': '2024-12-19T12:47:00.107',
#   'CRITICALNEWS': 0,
#   'ANNOUNCEMENT_TYPE': 'A',
#   'QUARTER_ID': None,
#   'FILESTATUS': 'N    ',
#   'ATTACHMENTNAME': '074f803b-4d54-4d05-a08c-b8586878bc1f.pdf',
#   'MORE': '',
#   'HEADLINE': 'Intimation under Regulation 39(3) of SEBI (Listing Obligations and Disclosure Requirements)',
#   'CATEGORYNAME': None,
#   'OLD': 1,
#   'RN': 1,
#   'PDFFLAG': 0,
#   'NSURL': 'https://www.bseindia.com/stock-share-price/the-byke-hospitality-ltd/byke/531373/',
#   'SLONGNAME': 'THE BYKE HOSPITALITY LTD.',
#   'AGENDA_ID': 177,
#   'TotalPageCnt': 4,
#   'News_submission_dt': '2024-12-19T12:46:59',
#   'DissemDT': '2024-12-19T12:47:00.107',
#   'TimeDiff': '00:00:01',
#   'Fld_Attachsize': 575580,
#   'SUBCATNAME': 'Reg. 39 (3) - Details of Loss of Certificate / Duplicate Certificate',
#   'AUDIO_VIDEO_FILE': None}]

# %%
def _store_announcement(stock_name: str, content: str, title:str) -> bool:
# async def _store_announcement(self, stock_name: str, content: str, summary: str, content_hash: str) -> bool:
    """Store announcement in recent_announcements_2 table"""
    try:
        data = {
            "stock_name": stock_name.upper(),
            "content": content,
            "title": title
            # "summary": summary,
            # "hash": content_hash
        }
        
        response = supabase_client.table('recent_announcements_2')\
            .upsert(data)\
            .execute()
            
        return len(response.data) > 0
    except Exception as e:
        print(f"Error storing announcement: {e}")
        return False

# %%
_store_announcement('TCS', 'test', 'test')
# Out:
# True

# %%
def process_announcement_content(announcement: Dict) -> tuple:
    """Process announcement content and generate summary"""
    try:
        pdf_name = announcement.get("ATTACHMENTNAME")
        title = announcement.get("MORE")
        if title == "":
            title = announcement.get("HEADLINE")
        return pdf_name, title
        
    except Exception as e:
        print(f"Error processing announcement content: {e}")
        return None, None

# %%
queue = AnnouncementQueue()

# %%
def queue_announcements() -> None:
    """Add new announcements to the processing queue"""
    print("Starting announcement check")
    start_time = time.time()
    
    announcements = fetch_new_announcements()
    queued_count = 0
    
    for announcement in announcements:
        try:
            company_code = announcement.get("SCRIP_CD")
            if not company_code:
                continue
            
            # Get company name
            company_name = get_company_name(str(company_code))
            if not company_name:
                continue

            # Process announcement content
            content, title = process_announcement_content(announcement)
            # if not content:
            #     continue

            # # Generate hash and check if already processed
            # content_hash = _generate_hash(content)
            print(f"get_company_name: {company_name} - {content}")
            if _check_existing_announcement(content):
                print(f"Announcement for {company_name} already exists")
                continue

            # Store in recent_announcements_2 table
            stored = _store_announcement(
                company_name,
                content,
                title
                # summary,
            )
            
            if stored:
                # Add to processing queue
                priority = 1  # Default priority
                added = queue.add_item(company_name, priority)
                if added:
                    queued_count += 1
                    print(f"Queued new announcement for {company_name}")
                
        except Exception as e:
            print(f"Error queuing announcement: {e}")
            continue

    execution_time = time.time() - start_time
    print(f"Announcement check completed. Queued {queued_count} new announcements in {execution_time:.2f} seconds")

# %%
queue_announcements()
# Out:
# Starting announcement check
# get_company_name: BDL - f3c61c91-f90b-41c2-8263-7fc45e7d8cba.pdf
# Announcement for BDL already exists
# get_company_name: BSOFT - BF8C2D1B_8A40_4582_A909_FCDDB69CBA7A_144128.pdf
# Announcement for BSOFT already exists
# get_company_name: HAPPSTMNDS - de24c299-8d81-4012-82d1-4087fc6b5899.pdf
# Announcement for HAPPSTMNDS already exists
# get_company_name: THOMASCOOK - 3ca75413-d3ae-4ec8-86d8-e93fcf383c7f.pdf
# Announcement for THOMASCOOK already exists
# get_company_name: SHANTIGEAR - 240439b7-30e7-4096-bc12-595e8edaaa5b.pdf
# Announcement for SHANTIGEAR already exists
# get_company_name: PTCIL - 58687b81-4943-4cdf-b93d-52a646753327.pdf
# Announcement for PTCIL already exists
# get_company_name: SARDAEN - 3e5bb1c3-4b01-4815-88a0-4dc9cd0c5da9.pdf
# Announcement for SARDAEN already exists
# get_company_name: GUJALKALI - 3f118a02-a328-4999-8c41-4ed29625e8e8.pdf
# Announcement for GUJALKALI already exists
# get_company_name: VOITHPAPR - 2deb3ce8-0134-402b-b812-9fbbb02b8e04.pdf
# Announcement for VOITHPAPR already exists
# get_company_name: PRIVISCL - 1b03d6c8-a459-4766-a504-9fd16626cfa4.pdf
# Announcement for PRIVISCL already exists
# get_company_name: IDEA - e97736f9-7599-4b30-9e8b-b3c839aa8fff.pdf
# Announcement for IDEA already exists
# get_company_name: SANGHIIND - 300f70f1-5170-4487-9cea-c89258f2f865.pdf
# Announcement for SANGHIIND already exists
# get_company_name: DHRUV - 445ef9e0-1789-4370-bd90-3781a7f14be9.pdf
# Announcement for DHRUV already exists
# get_company_name: IMAGICAA - 1f2ea3b6-0f52-499f-9a53-f912cd17aecd.pdf
# Announcement for IMAGICAA already exists
# get_company_name: HARDWYN - 55b74e49-5b66-4715-ba0d-c1d06296c4cd.pdf
# Announcement for HARDWYN already exists
# get_company_name: ATISHAY - e439f1c9-d918-4699-860d-3dcbddf1357a.pdf
# Announcement for ATISHAY already exists
# get_company_name: SPARC - 4d46a667-ac1b-4c57-9637-e3a5976b1443.pdf
# Announcement for SPARC already exists
# get_company_name: CCCL - 8498b933-ad5e-429d-9c8e-daea0d2a6468.pdf
# Announcement for CCCL already exists
# get_company_name: BIRLACABLE - 5c258ea7-1034-406a-a7fe-15d1de7abb32.pdf
# Announcement for BIRLACABLE already exists
# get_company_name: INDOWIND - 01450dd4-ea1a-44c5-b4b7-a9d8440d9457.pdf
# Announcement for INDOWIND already exists
# get_company_name: TASTYBITE - ebe7b596-7dd9-4934-b55c-f21755fd267e.pdf
# Announcement for TASTYBITE already exists
# get_company_name: CHEVIOT - 293020a5-93cc-4082-b6f6-923c6667c1e6.pdf
# Announcement for CHEVIOT already exists
# get_company_name: UNIABEXAL - 01111a4b-08bf-48a5-ae23-50f8f266eb9b.pdf
# Announcement for UNIABEXAL already exists
# get_company_name: BFUTILITIE - b25704b3-f73f-4ba7-8ca3-bc2bace06cf6.pdf
# Announcement for BFUTILITIE already exists
# get_company_name: GPIL - b30cfefe-8660-4c67-82ff-fe9ba6b12b58.pdf
# Announcement for GPIL already exists
# get_company_name: ADCINDIA - 48ca6a95-4974-4a6b-8d28-f4b3aebf4cdd.pdf
# Announcement for ADCINDIA already exists
# get_company_name: DECNGOLD - 8440d5e9-cf29-45bb-98bb-aef8fd58d6f6.pdf
# Announcement for DECNGOLD already exists
# get_company_name: PRSMJOHNSN - 64fb2d72-57d1-40f5-b691-2b44653d7b0b.pdf
# Announcement for PRSMJOHNSN already exists
# get_company_name: SOUTHWEST - 4d01eed1-3bc0-4945-aa4b-9f96b32021d4.pdf
# Announcement for SOUTHWEST already exists
# get_company_name: BYKE - 074f803b-4d54-4d05-a08c-b8586878bc1f.pdf
# Announcement for BYKE already exists
# Announcement check completed. Queued 0 new announcements in 4.48 seconds

# %%
_check_existing_announcement("445ef9e0-1789-4370-bd90-3781a7f14be9.pdf")
# Out:
# True
