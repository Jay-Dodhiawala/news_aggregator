# %%
from supabase import create_client
from langchain_community.embeddings import OpenAIEmbeddings
import os
from dotenv import load_dotenv

load_dotenv()

# Initialize your Supabase client here
url = os.getenv("SUPABASE_URL")
key = os.getenv("SUPABASE_KEY")
supabase_client = create_client(url, key)

# %%
def get_all_document_ids_from_chunks():
    """
    Get all unique document_ids from the metadata of chunks_v2 table

    Returns:
        list: A list of unique document IDs
    """
    try:
        limit = 1000  # Batch size for pagination
        document_ids = set()  # Using set to ensure uniqueness
        
        # First get the total count of chunks
        count_response = supabase_client.table('chunks_v2').select('*', count='exact').limit(1).execute()
        total_count = count_response.count if count_response.count else 0
        
        # Loop through all pages
        for start in range(0, total_count, limit):
            end = start + limit - 1  # Calculate the end index
            try:
                response = supabase_client.table('chunks_v2') \
                    .select('metadata->document_id') \
                    .range(start, end) \
                    .execute()
                
                # Extract document_ids from the response and add to set
                for chunk in response.data:
                    if chunk.get('document_id'):  # Ensure we have a document_id
                        document_ids.add(chunk['document_id'])
                
            except Exception as e:
                print(f"Error fetching range {start}-{end}: {e}")
                continue
        
        return list(document_ids)  # Convert set back to list for return
        
    except Exception as e:
        print(f"Error fetching document IDs: {e}")
        return []

# %%
chunks_document_ids = get_all_document_ids_from_chunks()

# Print the results
print(f"Found {len(chunks_document_ids)} unique document IDs")
# for doc_id in chunks_document_ids:
#     print(doc_id)
# Out:
# Found 12587 unique document IDs

# %%
def get_all_ids_from_documents():
    """
    Get all IDs from the documents table

    Returns:
        list: A list of document IDs
    """
    try:
        limit = 1000  # Batch size for pagination
        document_ids = []
        
        # First get the total count
        count_response = supabase_client.table('documents').select('*', count='exact').limit(1).execute()
        total_count = count_response.count if count_response.count else 0
        
        # Loop through all pages
        for start in range(0, total_count, limit):
            end = start + limit - 1  # Calculate the end index
            try:
                response = supabase_client.table('documents') \
                    .select('id') \
                    .range(start, end) \
                    .execute()
                
                # Extract ids from the response
                batch_ids = [doc['id'] for doc in response.data]
                document_ids.extend(batch_ids)
                
            except Exception as e:
                print(f"Error fetching range {start}-{end}: {e}")
                continue
        
        return document_ids
        
    except Exception as e:
        print(f"Error fetching IDs from documents: {e}")
        return []

# %%
document_ids = get_all_ids_from_documents()
print(f"Found {len(document_ids)} documents")
# Out:
# Found 12629 documents

# %%
# check if all document_ids from chunks are in documents
missing_ids = set(chunks_document_ids) - set(document_ids)

print(f"Missing IDs: {missing_ids} and length: {len(missing_ids)}")
# Out:
# Missing IDs: {'34be4194-bb6f-491d-ae1b-d6c225dd44dd', '97c5a655-4370-4ba8-a7f2-740b9c1aca47', '598ea37d-a232-4b31-9bc4-7048a8160855', 'e5ebd2c5-140c-468e-bf6b-62c0689f20e0', '0492e2cd-2761-4b97-b3cf-8c4de1c84afa', 'a98c9209-3c08-4e8d-8daf-ed02b1019f6e', '90c0872b-7cc9-4b16-9fa7-624087e0b232', '902894a5-1ec8-46cd-bb06-21a9d95ce107'} and length: 8

# %%
from typing import Optional, Dict, List, Tuple

def get_document_company_mapping() -> Dict[str, str]:
    """
    Get a mapping of document_id to company_id from documents table
    
    Returns:
        Dict[str, str]: Dictionary mapping document_id to company_id
    """
    try:
        mapping = {}
        limit = 1000
        
        # Get total count
        count_response = supabase_client.table('documents').select('*', count='exact').limit(1).execute()
        total_count = count_response.count if count_response.count else 0
        
        # Fetch all documents with their company_ids
        for start in range(0, total_count, limit):
            end = start + limit - 1
            response = supabase_client.table('documents') \
                .select('id, company_id') \
                .range(start, end) \
                .execute()
            
            # Build mapping
            for doc in response.data:
                if doc.get('id') and doc.get('company_id'):
                    mapping[doc['id']] = doc['company_id']
        
        return mapping
    except Exception as e:
        print(f"Error getting document-company mapping: {e}")
        return {}

def update_chunks_metadata_with_company_id() -> Tuple[int, int, int]:
    """
    Update the metadata of chunks_v2 to include company_id and remove invalid document_ids
    
    Returns:
        tuple: (success_count, error_count, removed_count)
    """
    try:
        # Get document to company mapping
        doc_company_mapping = get_document_company_mapping()
        if not doc_company_mapping:
            print("No document-company mappings found")
            return 0, 0, 0
        
        success_count = 0
        error_count = 0
        removed_count = 0
        limit = 1000
        
        # Get total count of chunks
        count_response = supabase_client.table('chunks_v2').select('*', count='exact').limit(1).execute()
        total_count = count_response.count if count_response.count else 0
        
        # Process chunks in batches
        for start in range(0, total_count, limit):
            try:
                # Fetch batch of chunks
                response = supabase_client.table('chunks_v2') \
                    .select('id, metadata') \
                    .range(start, start + limit - 1) \
                    .execute()
                
                # Process each chunk in the batch
                for chunk in response.data:
                    try:
                        metadata = chunk.get('metadata', {})
                        doc_id = metadata.get('document_id')
                        
                        # Skip if chunk already has company_id
                        if metadata.get('company_id'):
                            continue
                            
                        # If document_id doesn't exist in mapping, remove the chunk
                        if doc_id and doc_id not in doc_company_mapping:
                            try:
                                delete_response = supabase_client.table('chunks_v2') \
                                    .delete() \
                                    .eq('id', chunk['id']) \
                                    .execute()
                                    
                                if delete_response.data:
                                    removed_count += 1
                                    print(f"Removed chunk {chunk['id']} with invalid document_id: {doc_id}")
                                continue
                            except Exception as delete_error:
                                print(f"Error deleting chunk {chunk['id']}: {delete_error}")
                                error_count += 1
                                continue
                        
                        # Get company_id from mapping
                        company_id = doc_company_mapping.get(doc_id)
                        if not company_id:
                            continue
                        
                        # Update metadata with company_id
                        metadata['company_id'] = company_id
                        
                        # Update the chunk in database
                        update_response = supabase_client.table('chunks_v2') \
                            .update({'metadata': metadata}) \
                            .eq('id', chunk['id']) \
                            .execute()
                        
                        if update_response.data:
                            success_count += 1
                        else:
                            error_count += 1
                            
                    except Exception as chunk_error:
                        print(f"Error processing chunk {chunk.get('id')}: {chunk_error}")
                        error_count += 1
                        continue
                
                print(f"Processed batch {start}-{start+limit}:")
                print(f"- Successful updates: {success_count}")
                print(f"- Removed chunks: {removed_count}")
                print(f"- Errors: {error_count}")
                
            except Exception as batch_error:
                print(f"Error processing batch {start}-{start+limit}: {batch_error}")
                continue
        
        return success_count, error_count, removed_count
    
    except Exception as e:
        print(f"Error updating chunks metadata: {e}")
        return 0, 0, 0

# %%
# Update the metadata and remove invalid chunks
success, errors, removed = update_chunks_metadata_with_company_id()
print("\nUpdate Summary:")
print(f"Successful updates: {success}")
print(f"Chunks removed: {removed}")
print(f"Errors encountered: {errors}")

# # Verify the update
# stats = verify_metadata_update()
# print("\nCurrent Status:")
# print(f"Total chunks: {stats['total_chunks']}")
# print(f"Chunks with company_id: {stats['with_company_id']}")
# print(f"Chunks without company_id: {stats['without_company_id']}")
# print(f"Chunks with invalid document_ids: {stats['invalid_document_ids']}")
# print(f"Completion percentage: {stats['completion_percentage']}%")
# Out:
# Processed batch 0-1000:
# - Successful updates: 1
# - Removed chunks: 0
# - Errors: 0
# Processed batch 1000-2000:
# - Successful updates: 3
# - Removed chunks: 0
# - Errors: 0
# Processed batch 2000-3000:
# - Successful updates: 4
# - Removed chunks: 0
# - Errors: 0
# Processed batch 3000-4000:
# - Successful updates: 7
# - Removed chunks: 0
# - Errors: 0
# Processed batch 4000-5000:
# - Successful updates: 8
# - Removed chunks: 0
# - Errors: 0
# Processed batch 5000-6000:
# - Successful updates: 11
# - Removed chunks: 0
# - Errors: 0
# Processed batch 6000-7000:
# - Successful updates: 13
# - Removed chunks: 0
# - Errors: 0
# Processed batch 7000-8000:
# - Successful updates: 14
# - Removed chunks: 0
# - Errors: 0
# Processed batch 8000-9000:
# - Successful updates: 18
# - Removed chunks: 0
# - Errors: 0
# Processed batch 9000-10000:
# - Successful updates: 28
# - Removed chunks: 0
# - Errors: 0
# Processed batch 10000-11000:
# - Successful updates: 41
# - Removed chunks: 0
# - Errors: 0
# Processed batch 11000-12000:
# - Successful updates: 53
# - Removed chunks: 0
# - Errors: 0
# Processed batch 12000-13000:
# - Successful updates: 68
# - Removed chunks: 0
# - Errors: 0
# Processed batch 13000-14000:
# - Successful updates: 83
# - Removed chunks: 0
# - Errors: 0
# Processed batch 14000-15000:
# - Successful updates: 94
# - Removed chunks: 0
# - Errors: 0
# Processed batch 15000-16000:
# - Successful updates: 106
# - Removed chunks: 0
# - Errors: 0
# Processed batch 16000-17000:
# - Successful updates: 302
# - Removed chunks: 0
# - Errors: 0
# Processed batch 17000-18000:
# - Successful updates: 604
# - Removed chunks: 0
# - Errors: 0
# Processed batch 18000-19000:
# - Successful updates: 722
# - Removed chunks: 0
# - Errors: 0
# Processed batch 19000-20000:
# - Successful updates: 722
# - Removed chunks: 0
# - Errors: 0
# Processed batch 20000-21000:
# - Successful updates: 722
# - Removed chunks: 0
# - Errors: 0
# Processed batch 21000-22000:
# - Successful updates: 722
# - Removed chunks: 0
# - Errors: 0
#
# Update Summary:
# Successful updates: 722
# Chunks removed: 0
# Errors encountered: 0

# %%
def verify_metadata_update() -> Dict[str, int]:
    """
    Verify the metadata update by counting chunks with and without company_id
    
    Returns:
        Dict[str, int]: Statistics about the metadata update
    """
    try:
        # Count total chunks
        total_response = supabase_client.table('chunks_v2') \
            .select('*', count='exact') \
            .execute()
        total_chunks = total_response.count
        
        # Count chunks with company_id
        with_company_response = supabase_client.table('chunks_v2') \
            .select('*', count='exact') \
            .filter('metadata->>company_id', 'not.is', 'null') \
            .execute()
        with_company_id = with_company_response.count
        
        # Count chunks with document_id but without company_id
        invalid_doc_response = supabase_client.table('chunks_v2') \
            .select('*', count='exact') \
            .filter('metadata->>document_id', 'not.is', 'null') \
            .filter('metadata->>company_id', 'is', 'null') \
            .execute()
        invalid_doc_ids = invalid_doc_response.count
        
        # Calculate chunks without company_id
        without_company_id = total_chunks - with_company_id if total_chunks else 0
        
        return {
            'total_chunks': total_chunks,
            'with_company_id': with_company_id,
            'without_company_id': without_company_id,
            'invalid_document_ids': invalid_doc_ids,
            'completion_percentage': round((with_company_id / total_chunks * 100), 2) if total_chunks > 0 else 0
        }
        
    except Exception as e:
        print(f"Error verifying metadata update: {e}")
        import traceback
        print("Traceback:", traceback.format_exc())
        return {
            'total_chunks': 0,
            'with_company_id': 0,
            'without_company_id': 0,
            'invalid_document_ids': 0,
            'completion_percentage': 0
        }

# %%
# Verify the update
stats = verify_metadata_update()
print("\nCurrent Status:")
print(f"Total chunks: {stats['total_chunks']}")
print(f"Chunks with company_id: {stats['with_company_id']}")
print(f"Chunks without company_id: {stats['without_company_id']}")
print(f"Chunks with invalid document_ids: {stats['invalid_document_ids']}")
print(f"Completion percentage: {stats['completion_percentage']}%")
# Out:
# Current Status:
# Total chunks: 21332
# Chunks with company_id: 21300
# Chunks without company_id: 32
# Chunks with invalid document_ids: 32
# Completion percentage: 99.85%

# %%
from datetime import datetime, timedelta
import requests
from collections import defaultdict

def fetch_bse_data(
    pageno: str = "1",
    strCat: str = "Company Update",
    strPrevDate: Optional[str] = None,
    strScrip: str = "538734",
    strSearch: str = "P",
    strToDate: Optional[str] = None,
    strType: str = "C",
    subcategory: str = "-1"
) -> list:
    """
    Fetch data from the BSE API using the specified parameters.
    Defaults are used if values are not provided by the user.
    
    Parameters:
    - pageno: The page number for pagination (default: "1").
    - strCat: Category of the data, e.g., 'Board Meeting', 'AGM/EGM', 'Result' (default: 'Board Meeting').
    - strPrevDate: Starting date of the range in YYYYMMDD format (default: "20240718").
    - strScrip: Company Scrip Code (default: "532215").
    - strSearch: Search type (default: "P").
    - strToDate: End date of the range in YYYYMMDD format (default: "20241018").
    - strType: Type of the announcement (default: "C").
    - subcategory: Subcategory ID (default: "-1").
    - base_url: The base URL for the API request (default: BSE announcement API URL).

    Returns:
    - list of information if the request is successful.
    - Error message if the request fails.
    """
    category_subcategory_map = {
        "AGM/EGM": ["AGM"],
        "Board Meeting": ["Board Meeting", "Outcome of Board Meeting"],
        "Corp. Action": ["Sub-division/Stock Split", "Record Date", "Dividend", "Bonds/Right Issue", "Bonus"],
        "Result": ["Financial Results"],
        "Company Update": [
            "General",
            "Acquisition",
            "Allotment of Equity Shares",
            "Allotment of Warrants",
            "Award of Order / Receipt of Order",
            "Buy back",
            "Delisting",
            "Joint Venture",
            "Open Offer",
            "Debt Securities",
            "Credit Rating",
            "Shareholding",
            "Appointment of Director",
            "Appointment of Chairman",
            "Appointment of Chairman and Managing Director",
            "Appointment of Chief Executive Officer (CEO)",
            "Appointment of Chief Financial Officer (CFO)",
            "Appointment of Managing Director & CEO",
            "Increase of Authorised Capital",
            "Board Meeting Deferred",
            "Board Meeting Postponed",
            "Board Meeting Rescheduled",
            "Board Meeting Cancelled",
            "Resignation of Director",
            "Resignation of Chairman",
            "Resignation of Chairman and Managing Director",
            "Resignation of Chief Executive Officer (CEO)",
            "Resignation of Chief Financial Officer (CFO)",
            "Resignation of Managing Director",
            "Investor Presentation",
            "Change in Management",
            "Issue of Securities",
            "Offer for Sale",
            "Open Offer - Updates",
            "Post Buyback Public Announcement",
            "Post Offer Public Announcement",
            "Preferential Issue",
            "Qualified Institutional Placement",
            "Raising of Funds",
            "Restructuring",
            "Earnings Call Transcript",
            "Public Announcement",
            "Revision of outcome",
            "Funds raising by issuance of Debt Securities by Large Entities",
            "Amalgamation/ Merger",
            "De-merger",
            "Acquisition",
            "Update-Acquisition/Scheme/Sale/Disposal/Reg30",
            "Change in Directors/ Key Managerial Personnel/ Auditor/ Compliance Officer/ Share Transfer Agent",
        ]

        # "Company Update": ["General", "Award of Order/Receipt of Order"]
    }

    base_url = "https://api.bseindia.com/BseIndiaAPI/api/AnnSubCategoryGetData/w"

    # Get today's date and 1 year prior in the format YYYYMMDD
    today = datetime.now().strftime("%Y%m%d")
    if strCat == "Result":
        d = 730
    else:
        d = 364
    from_ = (datetime.now() - timedelta(days=d)).strftime("%Y%m%d")

    # Use provided date or default to calculated dates
    strToDate = strToDate if strToDate else today
    strPrevDate = strPrevDate if strPrevDate else from_
    
    params = {
        "pageno": pageno,
        "strCat": strCat,
        "strPrevDate": strPrevDate,
        "strScrip": strScrip,
        "strSearch": strSearch,
        "strToDate": strToDate,
        "strType": strType,
        "subcategory": subcategory
    }
    
    headers = {
        "referer": "https://www.bseindia.com/",
        "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.0.0 Safari/537.36"
    }
    
    response = requests.get(base_url, params=params, headers=headers)
    
    if response.status_code == 200:
        data = response.json()
        valid_subcategories = category_subcategory_map.get(strCat, [])
        
        if valid_subcategories:
            # Group items by subcategory
            subcategory_groups = defaultdict(list)
            for item in data["Table"]:
                subcategory_name = item.get("SUBCATNAME", "").strip()
                if subcategory_name in valid_subcategories:
                    subcategory_groups[subcategory_name].append(item)
            
            # Take top 2 items from each subcategory
            filtered_data = []
            for subcategory_items in subcategory_groups.values():
                filtered_data.extend(subcategory_items[:2])
            
            return filtered_data
        
        return data["Table"][:2]
    
    return []

# %%
def update_document_subcategories(scrip_code: str, supabase_client) -> None:
    """
    Update subcategories for existing documents in the database.
    
    Parameters:
    - scrip_code: The BSE scrip code for the company
    - supabase_client: Supabase client instance
    """
    # Fetch all documents for this scrip code
    documents = supabase_client.table('documents')\
        .select('id, pdf_name, category_name, upload_date')\
        .eq('company_code', scrip_code)\
        .is_('subcategory_name', 'null')\
        .execute()
    
    if not documents.data:
        print(f"No documents found for scrip code {scrip_code} without subcategories")
        return
    
    print(f"Found {len(documents.data)} documents to update")
    
    for doc in documents.data:
        category_name = doc['category_name']
        pdf_name = doc['pdf_name']
        doc_id = doc['id']
        # upload_date = doc['upload_date']
        
        # # Convert upload_date to required format for BSE API
        # upload_dt = datetime.strptime(upload_date, '%Y-%m-%d')
        # from_date = (upload_dt - timedelta(days=364)).strftime('%Y%m%d')
        # to_date = (upload_dt + timedelta(days=1)).strftime('%Y%m%d')
        
        # Fetch data from BSE API for this specific date range and category
        fetched_data = fetch_bse_data(
            strCat=category_name,
            strScrip=scrip_code,
        )
        
        # Find matching document and get its subcategory
        subcategory_name = None
        for item in fetched_data:
            if item.get("ATTACHMENTNAME") == pdf_name:
                subcategory_name = item.get("SUBCATNAME", "").strip()
                break
        
        if subcategory_name:
            # Update the document with the subcategory
            supabase_client.table('documents')\
                .update({"subcategory_name": subcategory_name})\
                .eq('id', doc_id)\
                .execute()
            print(f"Updated document {pdf_name} with subcategory: {subcategory_name}")
        else:
            print(f"Could not find subcategory for document {pdf_name}")

# %%
update_document_subcategories("507685", supabase_client)
# Out:
# Found 8 documents to update
# Updated document 60e5169e-2f58-4ead-8c35-b0126551eef3.pdf with subcategory: Outcome of Board Meeting
# Updated document 26de1531-8266-42e3-9b2e-602d1b70edc2.pdf with subcategory: Board Meeting
# Updated document 6a8df15b-8051-42dc-89c1-f4f50eccc895.pdf with subcategory: AGM
# Updated document 50dbf26d-6405-4120-9c12-3438febcd4b2.pdf with subcategory: AGM
# Updated document 64b0aa1f-f346-4dbf-a397-d1b722e71255.pdf with subcategory: Financial Results
# Updated document c0bffcde-52a6-4b89-8e57-b65f3df9274c.pdf with subcategory: Financial Results
# Updated document 4cc8c6b2-aa90-4745-a813-9b8ecb97f9fa.pdf with subcategory: General
# Updated document b8664611-9fd1-4127-a9af-9c2910d7cd83.pdf with subcategory: General

# %%
supabase_client.table('documents')\
    .update({"subcategory_name": "test"})\
    .eq('id', '0664da95-a810-4f17-95e1-569ba666dce7')\
    .execute()
# Out:
# APIResponse[~_ReturnT](data=[{'id': '0664da95-a810-4f17-95e1-569ba666dce7', 'company_code': '538734', 'pdf_name': 'dadf95c8-5ca8-4d4a-ad47-697d7380baf9.pdf', 'category_name': 'Company Update', 'upload_date': '2024-10-09', 'company_id': 'CEINSYSTECH', 'subcategory_name': 'test'}], count=None)

# %%
page_size = 1000
start = 0
all_documents = []

while True:
    # Get documents with pagination
    result = supabase_client.table('documents')\
        .select('id, pdf_name, category_name, company_code')\
        .is_('subcategory_name', 'null')\
        .range(start, start + page_size - 1)\
        .execute()
    
    if not result.data:
        break
        
    all_documents.extend(result.data)
    
    if len(result.data) < page_size:
        break
        
    start += page_size

total_documents = len(all_documents)
print(f"Found {total_documents} documents with null subcategories")
# Out:
# Found 15794 documents with null subcategories

# %%
unique_codes = set(doc['company_code'] for doc in all_documents)

# %%
for scrip_code in unique_codes:
    print(f"\nProcessing company with scrip code: {scrip_code}")
    update_document_subcategories(scrip_code, supabase_client)
# Out:
# Processing company with scrip code: 544003
# No documents found for scrip code 544003 without subcategories
#
# Processing company with scrip code: 544250
# No documents found for scrip code 544250 without subcategories
#
# Processing company with scrip code: 512070
# No documents found for scrip code 512070 without subcategories
#
# Processing company with scrip code: 500027
# Found 1 documents to update
# Could not find subcategory for document 9431fc2f-e124-492b-b646-9875fe5ae302.pdf
#
# Processing company with scrip code: 532400
# No documents found for scrip code 532400 without subcategories
#
# Processing company with scrip code: 530699
# No documents found for scrip code 530699 without subcategories
#
# Processing company with scrip code: 503101
# No documents found for scrip code 503101 without subcategories
#
# Processing company with scrip code: 505737
# No documents found for scrip code 505737 without subcategories
#
# Processing company with scrip code: 544131
# No documents found for scrip code 544131 without subcategories
#
# Processing company with scrip code: 500780
# No documents found for scrip code 500780 without subcategories
#
# Processing company with scrip code: 542725
# No documents found for scrip code 542725 without subcategories
#
# Processing company with scrip code: 532757
# No documents found for scrip code 532757 without subcategories
#
# Processing company with scrip code: 523710
# No documents found for scrip code 523710 without subcategories
#
# Processing company with scrip code: 541154
# No documents found for scrip code 541154 without subcategories
#
# Processing company with scrip code: 544055
# No documents found for scrip code 544055 without subcategories
#
# Processing company with scrip code: 515043
# No documents found for scrip code 515043 without subcategories
#
# Processing company with scrip code: 539594
# No documents found for scrip code 539594 without subcategories
#
# Processing company with scrip code: 531847
# No documents found for scrip code 531847 without subcategories
#
# Processing company with scrip code: 540048
# No documents found for scrip code 540048 without subcategories
#
# Processing company with scrip code: 543249
# No documents found for scrip code 543249 without subcategories
#
# Processing company with scrip code: 533676
# No documents found for scrip code 533676 without subcategories
#
# Processing company with scrip code: 534328
# No documents found for scrip code 534328 without subcategories
#
# Processing company with scrip code: 517041
# Found 1 documents to update
# Could not find subcategory for document a1f77fae-f92c-482d-9478-a91cef93cb15.pdf
#
# Processing company with scrip code: 541540
# No documents found for scrip code 541540 without subcategories
#
# Processing company with scrip code: 544219
# No documents found for scrip code 544219 without subcategories
#
# Processing company with scrip code: 542770
# No documents found for scrip code 542770 without subcategories
#
# Processing company with scrip code: 506235
# No documents found for scrip code 506235 without subcategories
#
# Processing company with scrip code: 543350
# No documents found for scrip code 543350 without subcategories
#
# Processing company with scrip code: 509546
# No documents found for scrip code 509546 without subcategories
#
# Processing company with scrip code: 522249
# No documents found for scrip code 522249 without subcategories
#
# Processing company with scrip code: 532485
# No documents found for scrip code 532485 without subcategories
#
# Processing company with scrip code: 532714
# No documents found for scrip code 532714 without subcategories
#
# Processing company with scrip code: 535789
# No documents found for scrip code 535789 without subcategories
#
# Processing company with scrip code: 543955
# No documents found for scrip code 543955 without subcategories
#
# Processing company with scrip code: 544004
# No documents found for scrip code 544004 without subcategories
#
# Processing company with scrip code: 533285
# No documents found for scrip code 533285 without subcategories
#
# Processing company with scrip code: 500186
# Found 1 documents to update
# Could not find subcategory for document c9c17463-6e10-42d7-82ca-91e3a78a4866.pdf
#
# Processing company with scrip code: 540952
# No documents found for scrip code 540952 without subcategories
#
# Processing company with scrip code: 543620
# No documents found for scrip code 543620 without subcategories
#
# Processing company with scrip code: 531727
# No documents found for scrip code 531727 without subcategories
#
# Processing company with scrip code: 509525
# No documents found for scrip code 509525 without subcategories
#
# Processing company with scrip code: 532673
# No documents found for scrip code 532673 without subcategories
#
# Processing company with scrip code: 532988
# No documents found for scrip code 532988 without subcategories
#
# Processing company with scrip code: 500101
# Found 3 documents to update
# Could not find subcategory for document b95f81af-3116-44ac-a17c-ae8037856f79.pdf
# Could not find subcategory for document 28a5bbdc-5972-427c-b56f-2e164b4d62d7.pdf
# Could not find subcategory for document 4057a5a7-b32c-41e2-9c6a-8d4963bd05aa.pdf
#
# Processing company with scrip code: 500233
# No documents found for scrip code 500233 without subcategories
#
# Processing company with scrip code: 517506
# No documents found for scrip code 517506 without subcategories
#
# Processing company with scrip code: 590071
# No documents found for scrip code 590071 without subcategories
#
# Processing company with scrip code: 539201
# No documents found for scrip code 539201 without subcategories
#
# Processing company with scrip code: 532967
# No documents found for scrip code 532967 without subcategories
#
# Processing company with scrip code: 526530
# No documents found for scrip code 526530 without subcategories
#
# Processing company with scrip code: 500201
# Found 3 documents to update
# Could not find subcategory for document a09a67c9-24a0-47ca-a6db-84c2450cad12.pdf
# Could not find subcategory for document d3631401-c12f-4515-b45d-6877b7171ead.pdf
# Could not find subcategory for document cc817b2e-5d96-496d-bbca-7d377c52a0c6.pdf
#
# Processing company with scrip code: 523539
# No documents found for scrip code 523539 without subcategories
#
# Processing company with scrip code: 500660
# No documents found for scrip code 500660 without subcategories
#
# Processing company with scrip code: 532440
# Found 3 documents to update
# Could not find subcategory for document 24c02911-1bce-46a9-8322-2211d5005cba.pdf
# Could not find subcategory for document 3628345a-1edf-4d4c-a65d-3421f6d16243.pdf
# Could not find subcategory for document 89fd691e-66ad-4c83-8e38-e941f72b58b0.pdf
#
# Processing company with scrip code: 533303
# No documents found for scrip code 533303 without subcategories
#
# Processing company with scrip code: 500298
# No documents found for scrip code 500298 without subcategories
#
# Processing company with scrip code: 544046
# No documents found for scrip code 544046 without subcategories
#
# Processing company with scrip code: 540750
# No documents found for scrip code 540750 without subcategories
#
# Processing company with scrip code: 523229
# No documents found for scrip code 523229 without subcategories
#
# Processing company with scrip code: 540900
# No documents found for scrip code 540900 without subcategories
#
# Processing company with scrip code: 500117
# Found 1 documents to update
# Could not find subcategory for document 7d2b657c-d51b-4892-aa61-8614380ecd33.pdf
#
# Processing company with scrip code: 532215
# No documents found for scrip code 532215 without subcategories
#
# Processing company with scrip code: 520056
# No documents found for scrip code 520056 without subcategories
#
# Processing company with scrip code: 532654
# No documents found for scrip code 532654 without subcategories
#
# Processing company with scrip code: 513375
# No documents found for scrip code 513375 without subcategories
#
# Processing company with scrip code: 540743
# No documents found for scrip code 540743 without subcategories
#
# Processing company with scrip code: 533023
# No documents found for scrip code 533023 without subcategories
#
# Processing company with scrip code: 507410
# No documents found for scrip code 507410 without subcategories
#
# Processing company with scrip code: 500028
# Found 1 documents to update
# Could not find subcategory for document a89af250-fc93-4eee-b881-b11905c4a7c8.pdf
#
# Processing company with scrip code: 543490
# No documents found for scrip code 543490 without subcategories
#
# Processing company with scrip code: 534675
# No documents found for scrip code 534675 without subcategories
#
# Processing company with scrip code: 544053
# No documents found for scrip code 544053 without subcategories
#
# Processing company with scrip code: 500550
# No documents found for scrip code 500550 without subcategories
#
# Processing company with scrip code: 530813
# No documents found for scrip code 530813 without subcategories
#
# Processing company with scrip code: 519600
# No documents found for scrip code 519600 without subcategories
#
# Processing company with scrip code: 520057
# No documents found for scrip code 520057 without subcategories
#
# Processing company with scrip code: 500049
# Found 1 documents to update
# Could not find subcategory for document aba33061-eda9-4f12-8150-2f9b5f63bf14.pdf
#
# Processing company with scrip code: 509480
# No documents found for scrip code 509480 without subcategories
#
# Processing company with scrip code: 538668
# No documents found for scrip code 538668 without subcategories
#
# Processing company with scrip code: 522014
# No documents found for scrip code 522014 without subcategories
#
# Processing company with scrip code: 543416
# Found 1 documents to update
# Could not find subcategory for document 5dbc0eb2-ca1c-4794-a4a9-be847b9ccea8.pdf
#
# Processing company with scrip code: 532313
# No documents found for scrip code 532313 without subcategories
#
# Processing company with scrip code: 543419
# No documents found for scrip code 543419 without subcategories
#
# Processing company with scrip code: 513023
# No documents found for scrip code 513023 without subcategories
#
# Processing company with scrip code: 532856
# No documents found for scrip code 532856 without subcategories
#
# Processing company with scrip code: 533302
# No documents found for scrip code 533302 without subcategories
#
# Processing company with scrip code: 514045
# Found 1 documents to update
# Could not find subcategory for document 9aa296c6-1bf9-42f8-884e-6b2559b019f0.pdf
#
# Processing company with scrip code: 530475
# No documents found for scrip code 530475 without subcategories
#
# Processing company with scrip code: 544235
# No documents found for scrip code 544235 without subcategories
#
# Processing company with scrip code: 513517
# No documents found for scrip code 513517 without subcategories
#
# Processing company with scrip code: 530163
# No documents found for scrip code 530163 without subcategories
#
# Processing company with scrip code: 543534
# No documents found for scrip code 543534 without subcategories
#
# Processing company with scrip code: 532827
# No documents found for scrip code 532827 without subcategories
#
# Processing company with scrip code: 533158
# No documents found for scrip code 533158 without subcategories
#
# Processing company with scrip code: 526953
# No documents found for scrip code 526953 without subcategories
#
# Processing company with scrip code: 500456
# No documents found for scrip code 500456 without subcategories
#
# Processing company with scrip code: 507815
# No documents found for scrip code 507815 without subcategories
#
# Processing company with scrip code: 543327
# Found 1 documents to update
# Could not find subcategory for document 0e0be808-507a-4bc4-88a2-1d663d94137c.pdf
#
# Processing company with scrip code: 511551
# No documents found for scrip code 511551 without subcategories
#
# Processing company with scrip code: 543278
# Found 1 documents to update
# Could not find subcategory for document e4aec5ea-47f7-4209-a40f-e60a4e825073.pdf
#
# Processing company with scrip code: 532366
# No documents found for scrip code 532366 without subcategories
#
# Processing company with scrip code: 540735
# No documents found for scrip code 540735 without subcategories
#
# Processing company with scrip code: 526829
# No documents found for scrip code 526829 without subcategories
#
# Processing company with scrip code: 543434
# No documents found for scrip code 543434 without subcategories
#
# Processing company with scrip code: 533155
# No documents found for scrip code 533155 without subcategories
#
# Processing company with scrip code: 532638
# No documents found for scrip code 532638 without subcategories
#
# Processing company with scrip code: 539921
# No documents found for scrip code 539921 without subcategories
#
# Processing company with scrip code: 542231
# No documents found for scrip code 542231 without subcategories
#
# Processing company with scrip code: 505242
# No documents found for scrip code 505242 without subcategories
#
# Processing company with scrip code: 532331
# No documents found for scrip code 532331 without subcategories
#
# Processing company with scrip code: 543272
# No documents found for scrip code 543272 without subcategories
#
# Processing company with scrip code: 542670
# No documents found for scrip code 542670 without subcategories
#
# Processing company with scrip code: 541353
# No documents found for scrip code 541353 without subcategories
#
# Processing company with scrip code: 535755
# Found 1 documents to update
# Could not find subcategory for document 672f46e1-59e6-4815-9410-ca71bc4f394e.pdf
#
# Processing company with scrip code: 532663
# No documents found for scrip code 532663 without subcategories
#
# Processing company with scrip code: 532983
# No documents found for scrip code 532983 without subcategories
#
# Processing company with scrip code: 531426
# No documents found for scrip code 531426 without subcategories
#
# Processing company with scrip code: 533320
# No documents found for scrip code 533320 without subcategories
#
# Processing company with scrip code: 511768
# No documents found for scrip code 511768 without subcategories
#
# Processing company with scrip code: 544037
# No documents found for scrip code 544037 without subcategories
#
# Processing company with scrip code: 537800
# No documents found for scrip code 537800 without subcategories
#
# Processing company with scrip code: 526783
# No documents found for scrip code 526783 without subcategories
#
# Processing company with scrip code: 523618
# No documents found for scrip code 523618 without subcategories
#
# Processing company with scrip code: 501295
# Found 1 documents to update
# Could not find subcategory for document 6ebe5e11-b958-401a-9dd7-a93f004c55b9.pdf
#
# Processing company with scrip code: 522241
# No documents found for scrip code 522241 without subcategories
#
# Processing company with scrip code: 500770
# No documents found for scrip code 500770 without subcategories
#
# Processing company with scrip code: 500199
# Found 2 documents to update
# Could not find subcategory for document 5a9b1bcd-29c8-4aa1-9614-8e31e0abad1d.pdf
# Could not find subcategory for document 0af8d37c-dc95-47e4-90d5-e77477e24ad8.pdf
#
# Processing company with scrip code: 507315
# No documents found for scrip code 507315 without subcategories
#
# Processing company with scrip code: 523736
# No documents found for scrip code 523736 without subcategories
#
# Processing company with scrip code: 535566
# Found 1 documents to update
# Could not find subcategory for document cee9a342-af73-442d-a767-2598cccfa44a.pdf
#
# Processing company with scrip code: 539562
# No documents found for scrip code 539562 without subcategories
#
# Processing company with scrip code: 500696
# No documents found for scrip code 500696 without subcategories
#
# Processing company with scrip code: 500480
# No documents found for scrip code 500480 without subcategories
#
# Processing company with scrip code: 502958
# No documents found for scrip code 502958 without subcategories
#
# Processing company with scrip code: 590013
# No documents found for scrip code 590013 without subcategories
#
# Processing company with scrip code: 524051
# No documents found for scrip code 524051 without subcategories
#
# Processing company with scrip code: 533761
# No documents found for scrip code 533761 without subcategories
#
# Processing company with scrip code: 543939
# No documents found for scrip code 543939 without subcategories
#
# Processing company with scrip code: 543330
# No documents found for scrip code 543330 without subcategories
#
# Processing company with scrip code: 543318
# No documents found for scrip code 543318 without subcategories
#
# Processing company with scrip code: 532650
# No documents found for scrip code 532650 without subcategories
#
# Processing company with scrip code: 533179
# No documents found for scrip code 533179 without subcategories
#
# Processing company with scrip code: 541450
# No documents found for scrip code 541450 without subcategories
#
# Processing company with scrip code: 544230
# No documents found for scrip code 544230 without subcategories
#
# Processing company with scrip code: 543596
# No documents found for scrip code 543596 without subcategories
#
# Processing company with scrip code: 524037
# No documents found for scrip code 524037 without subcategories
#
# Processing company with scrip code: 509820
# No documents found for scrip code 509820 without subcategories
#
# Processing company with scrip code: 532729
# No documents found for scrip code 532729 without subcategories
#
# Processing company with scrip code: 531859
# No documents found for scrip code 531859 without subcategories
#
# Processing company with scrip code: 531146
# No documents found for scrip code 531146 without subcategories
#
# Processing company with scrip code: 539837
# No documents found for scrip code 539837 without subcategories
#
# Processing company with scrip code: 532830
# No documents found for scrip code 532830 without subcategories
#
# Processing company with scrip code: 531112
# No documents found for scrip code 531112 without subcategories
#
# Processing company with scrip code: 540205
# No documents found for scrip code 540205 without subcategories
#
# Processing company with scrip code: 543600
# No documents found for scrip code 543600 without subcategories
#
# Processing company with scrip code: 537291
# No documents found for scrip code 537291 without subcategories
#
# Processing company with scrip code: 544162
# No documents found for scrip code 544162 without subcategories
#
# Processing company with scrip code: 532503
# No documents found for scrip code 532503 without subcategories
#
# Processing company with scrip code: 532644
# No documents found for scrip code 532644 without subcategories
#
# Processing company with scrip code: 531543
# No documents found for scrip code 531543 without subcategories
#
# Processing company with scrip code: 536773
# No documents found for scrip code 536773 without subcategories
#
# Processing company with scrip code: 543399
# No documents found for scrip code 543399 without subcategories
#
# Processing company with scrip code: 526666
# No documents found for scrip code 526666 without subcategories
#
# Processing company with scrip code: 531862
# No documents found for scrip code 531862 without subcategories
#
# Processing company with scrip code: 532522
# Found 2 documents to update
# Could not find subcategory for document 6a4ec6b7-d5d4-4569-a7ba-07fa6fe76c1e.pdf
# Could not find subcategory for document 2dc77eaf-d516-4e0f-8b93-6f5412e285ee.pdf
#
# Processing company with scrip code: 538666
# No documents found for scrip code 538666 without subcategories
#
# Processing company with scrip code: 543254
# No documents found for scrip code 543254 without subcategories
#
# Processing company with scrip code: 532754
# No documents found for scrip code 532754 without subcategories
#
# Processing company with scrip code: 543920
# No documents found for scrip code 543920 without subcategories
#
# Processing company with scrip code: 590073
# No documents found for scrip code 590073 without subcategories
#
# Processing company with scrip code: 532906
# No documents found for scrip code 532906 without subcategories
#
# Processing company with scrip code: 507488
# No documents found for scrip code 507488 without subcategories
#
# Processing company with scrip code: 543331
# No documents found for scrip code 543331 without subcategories
#
# Processing company with scrip code: 521016
# No documents found for scrip code 521016 without subcategories
#
# Processing company with scrip code: 524109
# No documents found for scrip code 524109 without subcategories
#
# Processing company with scrip code: 504731
# No documents found for scrip code 504731 without subcategories
#
# Processing company with scrip code: 532375
# No documents found for scrip code 532375 without subcategories
#
# Processing company with scrip code: 504903
# No documents found for scrip code 504903 without subcategories
#
# Processing company with scrip code: 502355
# No documents found for scrip code 502355 without subcategories
#
# Processing company with scrip code: 514354
# No documents found for scrip code 514354 without subcategories
#
# Processing company with scrip code: 533122
# No documents found for scrip code 533122 without subcategories
#
# Processing company with scrip code: 540797
# No documents found for scrip code 540797 without subcategories
#
# Processing company with scrip code: 890157
# No documents found for scrip code 890157 without subcategories
#
# Processing company with scrip code: 532921
# No documents found for scrip code 532921 without subcategories
#
# Processing company with scrip code: 504341
# No documents found for scrip code 504341 without subcategories
#
# Processing company with scrip code: 509079
# No documents found for scrip code 509079 without subcategories
#
# Processing company with scrip code: 502450
# No documents found for scrip code 502450 without subcategories
#
# Processing company with scrip code: 506022
# No documents found for scrip code 506022 without subcategories
#
# Processing company with scrip code: 500096
# Found 1 documents to update
# Could not find subcategory for document e9af2020-9d82-49c0-866f-7c323ade6bdb.pdf
#
# Processing company with scrip code: 507878
# No documents found for scrip code 507878 without subcategories
#
# Processing company with scrip code: 504614
# No documents found for scrip code 504614 without subcategories
#
# Processing company with scrip code: 512296
# No documents found for scrip code 512296 without subcategories
#
# Processing company with scrip code: 500067
# Found 3 documents to update
# Could not find subcategory for document 2680c601-e66e-4539-9410-206f4848a569.pdf
# Could not find subcategory for document 0d9df3c6-8d16-4124-ba7f-08341c510cd3.pdf
# Could not find subcategory for document ead15d73-f9f1-4fd3-abcf-cc24da682bd0.pdf
#
# Processing company with scrip code: 505854
# No documents found for scrip code 505854 without subcategories
#
# Processing company with scrip code: 517498
# No documents found for scrip code 517498 without subcategories
#
# Processing company with scrip code: 520008
# No documents found for scrip code 520008 without subcategories
#
# Processing company with scrip code: 530135
# No documents found for scrip code 530135 without subcategories
#
# Processing company with scrip code: 541019
# No documents found for scrip code 541019 without subcategories
#
# Processing company with scrip code: 500171
# Found 1 documents to update
# Could not find subcategory for document 23d8d075-6e49-422e-bc2b-1a02c720fc01.pdf
#
# Processing company with scrip code: 504058
# No documents found for scrip code 504058 without subcategories
#
# Processing company with scrip code: 526521
# No documents found for scrip code 526521 without subcategories
#
# Processing company with scrip code: 543958
# No documents found for scrip code 543958 without subcategories
#
# Processing company with scrip code: 513377
# No documents found for scrip code 513377 without subcategories
#
# Processing company with scrip code: 500039
# Found 1 documents to update
# Could not find subcategory for document b3242ea6-ef7f-4066-92a8-9471225f7176.pdf
#
# Processing company with scrip code: 500116
# No documents found for scrip code 500116 without subcategories
#
# Processing company with scrip code: 500183
# No documents found for scrip code 500183 without subcategories
#
# Processing company with scrip code: 500150
# Found 1 documents to update
# Could not find subcategory for document b8c15ebb-a629-441c-aa8c-faf2229edf63.pdf
#
# Processing company with scrip code: 532880
# No documents found for scrip code 532880 without subcategories
#
# Processing company with scrip code: 542919
# No documents found for scrip code 542919 without subcategories
#
# Processing company with scrip code: 539044
# No documents found for scrip code 539044 without subcategories
#
# Processing company with scrip code: 533295
# No documents found for scrip code 533295 without subcategories
#
# Processing company with scrip code: 532732
# No documents found for scrip code 532732 without subcategories
#
# Processing company with scrip code: 522285
# No documents found for scrip code 522285 without subcategories
#
# Processing company with scrip code: 524332
# No documents found for scrip code 524332 without subcategories
#
# Processing company with scrip code: 500219
# No documents found for scrip code 500219 without subcategories
#
# Processing company with scrip code: 513532
# Found 1 documents to update
# Could not find subcategory for document cf83a20e-c6ef-40fd-8829-1c86ca4c57c1.pdf
#
# Processing company with scrip code: 539141
# No documents found for scrip code 539141 without subcategories
#
# Processing company with scrip code: 504084
# No documents found for scrip code 504084 without subcategories
#
# Processing company with scrip code: 500133
# Found 2 documents to update
# Could not find subcategory for document 5e893902-1c39-47e7-89da-bb51bd3c14e5.pdf
# Could not find subcategory for document 6c065f1a-6b00-4ccf-9516-ad51c9fd99b1.pdf
#
# Processing company with scrip code: 539841
# No documents found for scrip code 539841 without subcategories
#
# Processing company with scrip code: 543652
# No documents found for scrip code 543652 without subcategories
#
# Processing company with scrip code: 543427
# No documents found for scrip code 543427 without subcategories
#
# Processing company with scrip code: 532624
# No documents found for scrip code 532624 without subcategories
pdf with subcategory: Financial Results
#
# Processing company with scrip code: 526367
# Found 6 documents to update
# Updated document 5619f1fb-32d0-4f45-a8f0-4265ad5a6090.pdf with subcategory: Outcome of Board Meeting
# Updated document 77fa75f1-5b16-4cb9-892c-f5d84aa77168.pdf with subcategory: Board Meeting
# Updated document f842bcb4-7cb2-41e4-ab19-3ea15a490800.pdf with subcategory: AGM
# Updated document 41c822c8-e804-4c6c-861d-cc2883bb1db3.pdf with subcategory: AGM
# Updated document 8002f8d2-2c2e-4870-a657-b6e997a3a5b4.pdf with subcategory: Financial Results
# Updated document 33fb3855-a917-481a-a1be-f38afdd1e555.pdf with subcategory: Financial Results
#
# Processing company with scrip code: 533284
# Found 14 documents to update
# Updated document 69489317-644c-4075-8ac1-5f83ea96cdf8.pdf with subcategory: Outcome of Board Meeting
# Updated document 01084237-9604-42c0-a344-302e764a1ab3.pdf with subcategory: Outcome of Board Meeting
# Updated document cd173da8-3f26-439e-9aa8-335a6dc78381.pdf with subcategory: Board Meeting
# Updated document 01c2d363-735c-4cec-b272-0b1300da4cab.pdf with subcategory: Board Meeting
# Updated document 8e9c0419-67d1-4ec0-b095-d4ad55ea5e46.pdf with subcategory: AGM
# Updated document ec2cef3e-070e-4786-bbd3-42b552822cea.pdf with subcategory: AGM
# Updated document 4972c5ee-45fb-428d-8b15-7a47954902bd.pdf with subcategory: Award of Order / Receipt of Order
# Updated document 3cdfec70-b99f-4242-9930-eac36c21ed90.pdf with subcategory: Award of Order / Receipt of Order
# Updated document f4d130e3-1e44-48b9-a33e-b1740e5e5bb9.pdf with subcategory: General
# Updated document 65c05090-e46e-4d07-bada-fbfd8fc8483f.pdf with subcategory: General
# Updated document 94b2199d-63b5-4514-897f-cc794c14801e.pdf with subcategory: Credit Rating
# Updated document 98ac5b06-8629-41b9-b4fb-cbf6188179ed.pdf with subcategory: Investor Presentation
# Updated document 44c8881e-5e0f-4964-a2aa-d90a46f4de62.pdf with subcategory: Financial Results
# Updated document 2fa3559a-e6bd-4035-976a-99a28358754e.pdf with subcategory: Financial Results
#
# Processing company with scrip code: 532508
# Found 6 documents to update
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File d:\project\bull_ai\news_aggregator\.venv\lib\site-packages\urllib3\connection.py:199, in HTTPConnection._new_conn(self)
#     198 try:
# --> 199     sock = connection.create_connection(
#     200         (self._dns_host, self.port),
#     201         self.timeout,
#     202         source_address=self.source_address,
#     203         socket_options=self.socket_options,
#     204     )
#     205 except socket.gaierror as e:
#
# File d:\project\bull_ai\news_aggregator\.venv\lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# File d:\project\bull_ai\news_aggregator\.venv\lib\site-packages\urllib3\util\connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#
# TimeoutError: [WinError 10060] A connection attempt failed because the connected party did not properly respond after a period of time, or established connection failed because connected host has failed to respond
#
# The above exception was the direct cause of the following exception:
#
# ConnectTimeoutError                       Traceback (most recent call last)
# File d:\project\bull_ai\news_aggregator\.venv\lib\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#
# File d:\project\bull_ai\news_aggregator\.venv\lib\site-packages\urllib3\connectionpool.py:490, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     489         new_e = _wrap_proxy_error(new_e, conn.proxy.scheme)
# --> 490     raise new_e
#     492 # conn.request() calls http.client.*.request, not the method in
#     493 # urllib3.request. It also calls makefile (recv) on the socket.
#
# File d:\project\bull_ai\news_aggregator\.venv\lib\site-packages\urllib3\connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     465 try:
# --> 466     self._validate_conn(conn)
#     467 except (SocketTimeout, BaseSSLError) as e:
#
# File d:\project\bull_ai\news_aggregator\.venv\lib\site-packages\urllib3\connectionpool.py:1095, in HTTPSConnectionPool._validate_conn(self, conn)
#    1094 if conn.is_closed:
# -> 1095     conn.connect()
#    1097 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# File d:\project\bull_ai\news_aggregator\.venv\lib\site-packages\urllib3\connection.py:693, in HTTPSConnection.connect(self)
#     692 sock: socket.socket | ssl.SSLSocket
# --> 693 self.sock = sock = self._new_conn()
#     694 server_hostname: str = self.host
#
# File d:\project\bull_ai\news_aggregator\.venv\lib\site-packages\urllib3\connection.py:208, in HTTPConnection._new_conn(self)
#     207 except SocketTimeout as e:
# --> 208     raise ConnectTimeoutError(
#     209         self,
#     210         f"Connection to {self.host} timed out. (connect timeout={self.timeout})",
#     211     ) from e
#     213 except OSError as e:
#
# ConnectTimeoutError: (<urllib3.connection.HTTPSConnection object at 0x000001FB388866E0>, 'Connection to api.bseindia.com timed out. (connect timeout=None)')
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File d:\project\bull_ai\news_aggregator\.venv\lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File d:\project\bull_ai\news_aggregator\.venv\lib\site-packages\urllib3\connectionpool.py:843, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     841     new_e = ProtocolError("Connection aborted.", new_e)
# --> 843 retries = retries.increment(
#     844     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     845 )
#     846 retries.sleep()
#
# File d:\project\bull_ai\news_aggregator\.venv\lib\site-packages\urllib3\util\retry.py:519, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     518     reason = error or ResponseError(cause)
# --> 519     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     521 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='api.bseindia.com', port=443): Max retries exceeded with url: /BseIndiaAPI/api/AnnSubCategoryGetData/w?pageno=1&strCat=Board+Meeting&strPrevDate=20231123&strScrip=532508&strSearch=P&strToDate=20241121&strType=C&subcategory=-1 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001FB388866E0>, 'Connection to api.bseindia.com timed out. (connect timeout=None)'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectTimeout                            Traceback (most recent call last)
# Cell In[29], line 3
#       1 for scrip_code in unique_codes:
#       2     print(f"\nProcessing company with scrip code: {scrip_code}")
# ----> 3     update_document_subcategories(scrip_code, supabase_client)
#
# Cell In[12], line 34, in update_document_subcategories(scrip_code, supabase_client)
#      25 doc_id = doc['id']
#      26 # upload_date = doc['upload_date']
#      27
#      28 # # Convert upload_date to required format for BSE API
#    (...)
#      32
#      33 # Fetch data from BSE API for this specific date range and category
# ---> 34 fetched_data = fetch_bse_data(
#      35     strCat=category_name,
#      36     strScrip=scrip_code,
#      37 )
#      39 # Find matching document and get its subcategory
#      40 subcategory_name = None
#
# Cell In[11], line 124, in fetch_bse_data(pageno, strCat, strPrevDate, strScrip, strSearch, strToDate, strType, subcategory)
#     108 params = {
#     109     "pageno": pageno,
#     110     "strCat": strCat,
#    (...)
#     116     "subcategory": subcategory
#     117 }
#     119 headers = {
#     120     "referer": "https://www.bseindia.com/",
#     121     "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.0.0 Safari/537.36"
#     122 }
# --> 124 response = requests.get(base_url, params=params, headers=headers)
#     126 if response.status_code == 200:
#     127     data = response.json()
#
# File d:\project\bull_ai\news_aggregator\.venv\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File d:\project\bull_ai\news_aggregator\.venv\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File d:\project\bull_ai\news_aggregator\.venv\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File d:\project\bull_ai\news_aggregator\.venv\lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File d:\project\bull_ai\news_aggregator\.venv\lib\site-packages\requests\adapters.py:688, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     685 if isinstance(e.reason, ConnectTimeoutError):
#     686     # TODO: Remove this in 3.0.0: see #2811
#     687     if not isinstance(e.reason, NewConnectionError):
# --> 688         raise ConnectTimeout(e, request=request)
#     690 if isinstance(e.reason, ResponseError):
#     691     raise RetryError(e, request=request)
#
# ConnectTimeout: HTTPSConnectionPool(host='api.bseindia.com', port=443): Max retries exceeded with url: /BseIndiaAPI/api/AnnSubCategoryGetData/w?pageno=1&strCat=Board+Meeting&strPrevDate=20231123&strScrip=532508&strSearch=P&strToDate=20241121&strType=C&subcategory=-1 (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x000001FB388866E0>, 'Connection to api.bseindia.com timed out. (connect timeout=None)'))

# %%
import time

def fetch_bse_data_with_retry(
    strCat: str,
    strScrip: str,
    max_retries: int = 3,
    timeout: int = 30,
    delay: int = 5
) -> list:
    """
    Fetch BSE data with retry logic and timeout handling.
    
    Parameters:
    - strCat: Category of data to fetch
    - strScrip: Company scrip code
    - max_retries: Maximum number of retry attempts
    - timeout: Timeout in seconds for each request
    - delay: Delay in seconds between retries
    """
    base_url = "https://api.bseindia.com/BseIndiaAPI/api/AnnSubCategoryGetData/w"

    # Get today's date and 1 year prior
    today = datetime.now().strftime("%Y%m%d")
    if strCat == "Result":
        d = 730
    else:
        d = 364
    from_ = (datetime.now() - timedelta(days=d)).strftime("%Y%m%d")
    
    params = {
        "pageno": "1",
        "strCat": strCat,
        "strPrevDate": from_,
        "strScrip": strScrip,
        "strSearch": "P",
        "strToDate": today,
        "strType": "C",
        "subcategory": "-1"
    }
    
    headers = {
        "referer": "https://www.bseindia.com/",
        "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.0.0 Safari/537.36"
    }

    for attempt in range(max_retries):
        try:
            response = requests.get(
                base_url, 
                params=params, 
                headers=headers,
                timeout=timeout
            )
            
            if response.status_code == 200:
                data = response.json()
                return data.get("Table", [])[:2]
            
        except (requests.ConnectionError, requests.Timeout) as e:
            print(f"Attempt {attempt + 1} failed: {str(e)}")
            if attempt < max_retries - 1:
                print(f"Waiting {delay} seconds before retrying...")
                time.sleep(delay)
            continue
            
    print(f"Failed to fetch data after {max_retries} attempts")
    return []

def update_all_null_subcategories():
    """
    Get all documents with null subcategories using pagination and process them one by one.
    """
    # supabase_client = create_supabase_client()
    
    # Initialize variables for pagination
    page_size = 1000
    start = 0
    all_documents = []
    
    while True:
        # Get documents with pagination
        result = supabase_client.table('documents')\
            .select('id, pdf_name, category_name, company_code')\
            .is_('subcategory_name', 'null')\
            .range(start, start + page_size - 1)\
            .execute()
        
        if not result.data:
            break
            
        all_documents.extend(result.data)
        
        if len(result.data) < page_size:
            break
            
        start += page_size
    
    # Group documents by company code
    company_docs = {}
    for doc in all_documents:
        company_code = doc['company_code']
        if company_code not in company_docs:
            company_docs[company_code] = []
        company_docs[company_code].append(doc)
    
    total_companies = len(company_docs)
    print(f"Found {len(all_documents)} documents across {total_companies} companies")
    
    # Process each company's documents
    for idx, (company_code, docs) in enumerate(company_docs.items(), 1):
        print(f"\nProcessing company {idx}/{total_companies} with scrip code: {company_code}")
        
        # Group documents by category
        category_docs = {}
        for doc in docs:
            category = doc['category_name']
            if category not in category_docs:
                category_docs[category] = []
            category_docs[category].append(doc)
        
        # Process each category
        for category, category_docs_list in category_docs.items():
            print(f"Fetching data for category: {category}")
            
            # Get data from BSE API with retry logic
            fetched_data = fetch_bse_data_with_retry(
                strCat=category,
                strScrip=company_code
            )
            
            # Create mapping of pdf_name to subcategory
            pdf_subcategory_map = {
                item["ATTACHMENTNAME"]: item.get("SUBCATNAME", "").strip()
                for item in fetched_data
            }
            
            # Update documents
            for doc in category_docs_list:
                subcategory = pdf_subcategory_map.get(doc['pdf_name'])
                if subcategory:
                    try:
                        supabase_client.table('documents')\
                            .update({"subcategory_name": subcategory})\
                            .eq('id', doc['id'])\
                            .execute()
                        print(f"Updated document {doc['pdf_name']} with subcategory: {subcategory}")
                    except Exception as e:
                        print(f"Error updating document {doc['pdf_name']}: {str(e)}")
                else:
                    print(f"Could not find subcategory for document {doc['pdf_name']}")
        
        # Add a small delay between companies to avoid rate limiting
        time.sleep(2)

# Usage:
# update_all_null_subcategories()

# %%
update_all_null_subcategories()
# Out:
# Found 12644 documents across 1557 companies
#
# Processing company 1/1557 with scrip code: 543237
# Fetching data for category: Board Meeting
# Updated document 88b6849e-dcec-4719-ad2f-38b848059f38.pdf with subcategory: Board Meeting
# Updated document 89c30338-afdb-4f89-914e-03a2864cf87d.pdf with subcategory: Outcome of Board Meeting
# Fetching data for category: AGM/EGM
# Updated document 463b9244-7e5e-4d81-abf2-af8ca3146aa5.pdf with subcategory: AGM
# Could not find subcategory for document 7e29cf4d-4afc-4349-8d16-e73fd9aa5293.pdf
# Fetching data for category: Result
# Updated document df9ca914-8be6-4b41-9332-ac5457c24f2e.pdf with subcategory: Financial Results
# Updated document 3154380d-a851-4f1b-850a-2cfe6dd93fc2.pdf with subcategory: Financial Results
#
# Processing company 2/1557 with scrip code: 532477
# Fetching data for category: Board Meeting
# Updated document 5d399273-1d01-406d-aa03-41cdf0c2b94c.pdf with subcategory: Outcome of Board Meeting
# Updated document df83e01d-e618-4040-9414-f70eb6a1f439.pdf with subcategory: Board Meeting
# Fetching data for category: AGM/EGM
# Updated document 21dc633d-d74a-4ab7-ba9f-a3c51abe6bcc.pdf with subcategory: AGM
# Updated document 7fa2edaf-9f75-4cd8-95ad-c6b4af72d6cf.pdf with subcategory: AGM
# Fetching data for category: Result
# Updated document eef5aeb3-8039-42fa-a243-32f27be1e247.pdf with subcategory: Financial Results
# Updated document 41c9a59c-fb2f-4e6f-9a1e-5f7a9e7cc4a7.pdf with subcategory: Financial Results
#
# Processing company 3/1557 with scrip code: 543278
# Fetching data for category: Result
# Could not find subcategory for document e4aec5ea-47f7-4209-a40f-e60a4e825073.pdf
#
# Processing company 4/1557 with scrip code: 539523
# Fetching data for category: Board Meeting
# Updated document df46e8c5-1eaf-447f-93ec-49794ec89f33.pdf with subcategory: Board Meeting
# Could not find subcategory for document fa070205-1105-44b7-af97-76cebad5ae99.pdf
# Updated document 53d8457f-8f32-42db-9f1d-1c965b384dc0.pdf with subcategory: Outcome of Board Meeting
# Fetching data for category: AGM/EGM
# Could not find subcategory for document
pdf with subcategory: AGM
# Fetching data for category: Result
# Updated document 1efe9e68-3c98-421b-aff4-f85f6e0fde8b.pdf with subcategory: Financial Results
# Updated document 0913bf33-c1ff-4f83-bf53-2afafa1021c2.pdf with subcategory: Financial Results
#
# Processing company 9/1557 with scrip code: 532843
# Fetching data for category: Board Meeting
# Updated document ed0c54ea-d60d-4f94-99f2-640ce1f2007e.pdf with subcategory: Outcome of Board Meeting
# Updated document 83f19a4f-675d-4939-bd13-1fbdd6e66860.pdf with subcategory: Board Meeting
# Fetching data for category: AGM/EGM
# Could not find subcategory for document 5f4aa3af-d9a9-4869-9211-8283727d9324.pdf
# Could not find subcategory for document 307ef8f6-e2dd-4f7f-9823-f46e4b27cb7c.pdf
# Fetching data for category: Result
# Updated document e198151f-489a-4773-9770-d3897907d063.pdf with subcategory: Financial Results
# Updated document 79c619d5-bc4d-4ea4-8e55-668e49b91943.pdf with subcategory: Financial Results
#
# Processing company 10/1557 with scrip code: 500410
# Fetching data for category: Result
# Updated document 10b88ee4-8397-4aec-aa11-676b70e86517.pdf with subcategory: Financial Results
# Updated document a0fe9608-d0ac-4e51-b30d-922645f1e663.pdf with subcategory: Financial Results
# Fetching data for category: Board Meeting
# Updated document da882670-f11e-4a6e-88e8-7cbb2bc96fff.pdf with subcategory: Outcome of Board Meeting
# Updated document bfa08a1f-6890-428a-9857-4279f77c1fa7.pdf with subcategory: Board Meeting
# Fetching data for category: AGM/EGM
# Updated document 294e52bc-d49b-48ca-908c-65ff6d2adb9e.pdf with subcategory: AGM
# Updated document 273779a4-c0f0-4c6f-a632-4d90743829ee.pdf with subcategory: AGM
#
# Processing company 11/1557 with scrip code: 532822
# Fetching data for category: Result
# Updated document 54dfe769-0f91-4729-b37c-c2257ef070dd.pdf with subcategory: Financial Results
# Updated document 08b543c2-5154-4030-ba44-63d1525f8d61.pdf with subcategory: Financial Results
# Could not find subcategory for document 727845d5-f12b-4f6f-af01-8d8d1462e7b7.pdf
# Fetching data for category: Board Meeting
# Updated document 421976af-5157-4eec-92c2-5ed64f4f62f5.pdf with subcategory: Board Meeting
# Updated document afc5b73e-502c-4004-b052-c2fc894b8779.pdf with subcategory: Board Meeting
# Fetching data for category: AGM/EGM
# Could not find subcategory for document 893ea5e4-3439-4e82-96b5-714bef66e0cc.pdf
# Could not find subcategory for document 3017207a-102a-4e2f-8437-9500fef32a05.pdf
#
# Processing company 12/1557 with scrip code: 543664
# Fetching data for category: Result
# Updated document 5c6e939d-b6ae-480d-8be7-f289526fbc8b.pdf with subcategory: Financial Results
# Updated document b1ea1663-51c0-4b97-98c1-1f11c18c6518.pdf with subcategory: Financial Results
# Fetching data for category: Board Meeting
# Updated document aee1a18d-fc8f-4c1b-9e75-f8f9665132ad.pdf with subcategory: Outcome of Board Meeting
# Updated document 3bd4dc80-fd9e-46dd-89c3-a28f04a3f950.pdf with subcategory: Board Meeting
# Fetching data for category: AGM/EGM
# Updated document 08af06e8-9cc7-4b68-8ae2-c5813a862074.pdf with subcategory: AGM
# Updated document b3f6a529-6d04-4e34-8720-cda8de6668f2.pdf with subcategory: AGM
#
# Processing company 13/1557 with scrip code: 543426
# Fetching data for category: Board Meeting
# Updated document bb25d9b1-aa4f-45a5-b5ac-85ee9f4fd757.pdf with subcategory: Outcome of Board Meeting
# Updated document 26bb2cc6-2d92-45af-83aa-be5d740e3cb6.pdf with subcategory: Board Meeting
# Fetching data for category: AGM/EGM
# Updated document c7c3c61a-5e54-4325-945a-ebaf38852fd7.pdf with subcategory: AGM
# Updated document 9e80585d-79fd-4c28-8098-2f39ebe0e340.pdf with subcategory: AGM
# Fetching data for category: Result
# Updated document
board Meeting
# Fetching data for category: AGM/EGM
# Could not find subcategory for document 670a516b-4d0d-4502-98a5-e5d1e290855e.pdf
# Could not find subcategory for document 148e342c-d1bc-4791-9299-febfc134cf35.pdf
# Fetching data for category: Result
# Updated document b22e0d72-34df-41e6-b866-dfb0a5aec9a8.pdf with subcategory: Financial Results
# Updated document 832e2ded-8e7f-4eaa-8e1e-b2ad23515251.pdf with subcategory: Financial Results
#
# Processing company 55/1557 with scrip code: 500164
# Fetching data for category: Board Meeting
# Updated document 8479f4f1-f738-46d3-9f51-a06962cb0c03.pdf with subcategory: Outcome of Board Meeting
# Updated document 40178d1f-9837-4f74-b4a8-14b563fea2f5.pdf with subcategory: Board Meeting
# Could not find subcategory for document 7b603c00-b350-49c6-9a7f-bceba6673c70.pdf
# Could not find subcategory for document ef62a860-80b7-43d0-8d57-775d84c3daba.pdf
# Fetching data for category: AGM/EGM
# Could not find subcategory for document 2c2c08bb-df3e-4d7d-af62-b1ee659e31cb.pdf
# Could not find subcategory for document ce44e17a-aeee-4e9c-b4f5-67a729d60ca7.pdf
# Updated document 43f37e8f-6a85-4f8b-ace7-1da43c27a3c8.pdf with subcategory: Postal Ballot
# Updated document 3533d12e-f8f6-412f-b201-6aaed14bda07.pdf with subcategory: Postal Ballot
# Fetching data for category: Result
# Updated document 6b6f22f0-6efa-46a5-90e5-70679e8b6646.pdf with subcategory: Financial Results
# Updated document 4611aa48-bfca-4c69-9ad7-500d49a2e471.pdf with subcategory: Financial Results
# Could not find subcategory for document 1f3ace00-1d0e-4214-80fc-a62d7ae12c9a.pdf
#
# Processing company 56/1557 with scrip code: 543635
# Fetching data for category: Board Meeting
# Updated document 68e778e5-0e4b-4102-8e51-8f5ce3fe5b6a.pdf with subcategory: Outcome of Board Meeting
# Updated document e5ac0b18-8890-4273-a417-9549306401d3.pdf with subcategory: Board Meeting
# Fetching data for category: AGM/EGM
# Updated document 44870d01-4114-4da0-b106-ebf7ecef19c4.pdf with subcategory: AGM
# Updated document 7f8ef907-eef2-4ce1-a9cb-c7531ee21a8c.pdf with subcategory: AGM
# Fetching data for category: Result
# Updated document bd57c8cf-1d4a-4ed3-8967-4182ba3cbaac.pdf with subcategory: Financial Results
# Updated document f697efe5-4196-4896-8241-84e6f3936ce6.pdf with subcategory: Financial Results
#
# Processing company 57/1557 with scrip code: 543498
# Fetching data for category: Board Meeting
# Updated document a98f14f2-ed0c-4d50-8290-1de67a61b3fc.pdf with subcategory: Board Meeting
# Updated document f51b2f69-0e02-4269-9abf-f47d5789ef68.pdf with subcategory: Board Meeting
# Fetching data for category: AGM/EGM
# Updated document bcbafd9f-277c-4f16-b8c2-5b797b65d45c.pdf with subcategory: AGM
# Updated document 72d50bc4-29bf-4460-a629-f4cedf20c632.pdf with subcategory: AGM
# Fetching data for category: Result
# Updated document f5a484cf-5c82-463b-9d9b-bb3fe1305c4c.pdf with subcategory: Financial Results
# Updated document e7b40e46-c4bc-447f-ab13-95cab1bdd454.pdf with subcategory: Financial Results
#
# Processing company 58/1557 with scrip code: 532522
# Fetching data for category: AGM/EGM
# Updated document 6a4ec6b7-d5d4-4569-a7ba-07fa6fe76c1e.pdf with subcategory: Postal Ballot
# Fetching data for category: Result
# Could not find subcategory for document 2dc77eaf-d516-4e0f-8b93-6f5412e285ee.pdf
#
# Processing company 59/1557 with scrip code: 500074
# Fetching data for category: Result
# Updated document 2af50f7d-aeda-4a8a-9ca4-de516c085462.pdf with subcategory: Financial Results
# Could not find subcategory for document 75230eca-6a91-47f7-87ec-1f98afa79224.pdf
